# %%
import numpy as np
import pandas as pd

# %%
reviews = pd.read_csv('all_kindle_review.csv')

# %%
reviews
# Out:
#        Unnamed: 0.1  Unnamed: 0        asin  helpful  rating  \
# 0                 0       11539  B0033UV8HI  [8, 10]       3
# 1                 1        5957  B002HJV4DE   [1, 1]       5
# 2                 2        9146  B002ZG96I4   [0, 0]       3
# 3                 3        7038  B002QHWOEU   [1, 3]       3
# 4                 4        1776  B001A06VJ8   [0, 1]       4
# ...             ...         ...         ...      ...     ...
# 11995         11995        2183  B001DUGORO   [0, 0]       4
# 11996         11996        6272  B002JCSFSQ   [2, 2]       5
# 11997         11997       12483  B0035N1V7K   [0, 1]       3
# 11998         11998        3640  B001W1XT40   [1, 2]       1
# 11999         11999       11398  B003370JUS   [5, 6]       3
#
#                                               reviewText   reviewTime  \
# 0      Jace Rankin may be short, but he's nothing to ...   09 2, 2010
# 1      Great short read.  I didn't want to put it dow...   10 8, 2013
# 2      I'll start by saying this is the first of four...  04 11, 2014
# 3      Aggie is Angela Lansbury who carries pocketboo...   07 5, 2014
# 4      I did not expect this type of book to be in li...  12 31, 2012
# ...                                                  ...          ...
# 11995  Valentine cupid is a vampire- Jena and Ian ano...  02 28, 2014
# 11996  I have read all seven books in this series. Ap...  05 16, 2011
# 11997  This book really just wasn't my cuppa.  The si...  07 26, 2013
# 11998  tried to use it to charge my kindle, it didn't...  09 17, 2013
# 11999  Taking Instruction is a look into the often hi...   07 5, 2012
#
#            reviewerID                   reviewerName  \
# 0      A3HHXRELK8BHQG                         Ridley
# 1      A2RGNZ0TRF578I                   Holly Butler
# 2      A3S0H2HV6U1I7F                        Merissa
# 3       AC4OQW3GZ919J                     Cleargrace
# 4      A3C9V987IQHOQD                       Rjostler
# ...               ...                            ...
# 11995  A1OKS5Q1HD8WQC                  lisa jon jung
# 11996   AQRSPXLNEQAMA                        TerryLP
# 11997  A2T5QLT5VXOJAK                        hwilson
# 11998  A28MHD2DDY6DXB  Allison A. Slater "Gryphon50"
# 11999  A3JUXLB4K9ZXCC                      Dafna Yee
#
#                                                  summary  unixReviewTime
# 0                               Entertaining But Average      1283385600
# 1                                Terrific menage scenes!      1381190400
# 2                                       Snapdragon Alley      1397174400
# 3                                 very light murder cozy      1404518400
# 4                                                   Book      1356912000
# ...                                                  ...             ...
# 11995                                               jena      1393545600
# 11996                                Peacekeepers Series      1305504000
# 11997                                    a little creepy      1374796800
# 11998                                        didn't work      1379376000
# 11999  If you like BDSM with a touch of romance, this...      1341446400
#
# [12000 rows x 11 columns]

# %%
reviews = reviews[['reviewText', 'rating']]

# %%
reviews
# Out:
#                                               reviewText  rating
# 0      Jace Rankin may be short, but he's nothing to ...       3
# 1      Great short read.  I didn't want to put it dow...       5
# 2      I'll start by saying this is the first of four...       3
# 3      Aggie is Angela Lansbury who carries pocketboo...       3
# 4      I did not expect this type of book to be in li...       4
# ...                                                  ...     ...
# 11995  Valentine cupid is a vampire- Jena and Ian ano...       4
# 11996  I have read all seven books in this series. Ap...       5
# 11997  This book really just wasn't my cuppa.  The si...       3
# 11998  tried to use it to charge my kindle, it didn't...       1
# 11999  Taking Instruction is a look into the often hi...       3
#
# [12000 rows x 2 columns]

# %%
reviews['rating'] = reviews['rating'].apply(lambda x:0 if x<3 else 1)
# Out:
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\3889068617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['rating'] = reviews['rating'].apply(lambda x:0 if x<3 else 1)

# %%
reviews
# Out:
#                                               reviewText  rating
# 0      Jace Rankin may be short, but he's nothing to ...       1
# 1      Great short read.  I didn't want to put it dow...       1
# 2      I'll start by saying this is the first of four...       1
# 3      Aggie is Angela Lansbury who carries pocketboo...       1
# 4      I did not expect this type of book to be in li...       1
# ...                                                  ...     ...
# 11995  Valentine cupid is a vampire- Jena and Ian ano...       1
# 11996  I have read all seven books in this series. Ap...       1
# 11997  This book really just wasn't my cuppa.  The si...       1
# 11998  tried to use it to charge my kindle, it didn't...       0
# 11999  Taking Instruction is a look into the often hi...       1
#
# [12000 rows x 2 columns]

# %%
reviews['reviewText'] = reviews['reviewText'].str.lower()
# Out:
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\3655943723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['reviewText'] = reviews['reviewText'].str.lower()

# %%
import re
import nltk
from nltk.corpus import stopwords
from bs4 import BeautifulSoup

reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x:re.sub('[^a-z A-Z 0-9]+', ' ', x))

# Removing stopwords
reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x:" ".join([word for word in x.split() if word not in stopwords.words('english')]))

## Remove url 
reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x: re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', '' , str(x)))

## Remove html tags
reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

## Remove any additional spaces
reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x: " ".join(x.split()))
# Out:
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\2310369933.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x:re.sub('[^a-z A-Z 0-9]+', ' ', x))
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\2310369933.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x:" ".join([word for word in x.split() if word not in stopwords.words('english')]))
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\2310369933.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x: re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', '' , str(x)))
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\2310369933.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
# C:\Users\91780\AppData\Local\Temp\ipykernel_17424\2310369933.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews.loc[:, 'reviewText'] = reviews['reviewText'].apply(lambda x: " ".join(x.split()))

# %%
reviews.shape
# Out:
# (12000, 2)

# %%
corpus = reviews['reviewText']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
words = [review.split() for review in corpus]
lemmatized_word = []
for review in words:
    lemmatized_review = [lemmatizer.lemmatize(word, pos="v") for word in review]
    lemmatized_word.append(lemmatized_review)

# %%
corpus
# Out:
# 0        jace rankin may short nothing mess man hauled ...
# 1        great short read want put read one sitting sex...
# 2        start saying first four books expecting 34 con...
# 3        aggie angela lansbury carries pocketbooks inst...
# 4        expect type book library pleased find price right
#                                ...
# 11995    valentine cupid vampire jena ian another vampi...
# 11996    read seven books series apocalyptic adventure ...
# 11997    book really cuppa situation man capturing woma...
# 11998    tried use charge kindle even register charging...
# 11999    taking instruction look often hidden world sex...
# Name: reviewText, Length: 12000, dtype: object

# %%
lemmatized_word
# Out:
# [['jace',
#   'rankin',
#   'may',
#   'short',
#   'nothing',
#   'mess',
#   'man',
#   'haul',
#   'saloon',
#   'undertaker',
#   'know',
#   'famous',
#   'bounty',
#   'hunter',
#   'oregon',
#   '1890s',
#   'shoot',
#   'man',
#   'saloon',
#   'finish',
#   'years',
#   'long',
#   'quest',
#   'avenge',
#   'sister',
#   'murder',
#   'try',
#   'figure',
#   'next',
#   'snotty',
#   'nose',
#   'farm',
#   'boy',
#   'rescue',
#   'gang',
#   'bully',
#   'offer',
#   'money',
#   'kill',
#   'man',
#   'force',
#   'ranch',
#   'reluctantly',
#   'agree',
#   'bring',
#   'man',
#   'justice',
#   'kill',
#   'outright',
#   'first',
#   'need',
#   'tell',
#   'sister',
#   'widower',
#   'news',
#   'kyla',
#   'kyle',
#   'springer',
#   'bailey',
#   'rid',
#   'trail',
#   'sleep',
#   'grind',
#   'past',
#   'month',
#   'try',
#   'find',
#   'jace',
#   'want',
#   'revenge',
#   'man',
#   'kill',
#   'husband',
#   'take',
#   'ranch',
#   'amongst',
#   'crimes',
#   'keen',
#   'detour',
#   'jace',
#   'want',
#   'take',
#   'realize',
#   'options',
#   'hide',
#   'behind',
#   'boy',
#   'persona',
#   'best',
#   'try',
#   'keep',
#   'pace',
#   'confrontation',
#   'along',
#   'way',
#   'get',
#   'shoot',
#   'jace',
#   'discover',
#   'kyle',
#   'kyla',
#   'come',
#   'clean',
#   'whole',
#   'reason',
#   'need',
#   'scoundrel',
#   'dead',
#   'hope',
#   'still',
#   'help',
#   'book',
#   'share',
#   'touch',
#   'moments',
#   'slow',
#   'bloom',
#   'romance',
#   'kyla',
#   'find',
#   'good',
#   'reason',
#   'fear',
#   'men',
#   'hide',
#   'behind',
#   'boy',
#   'persona',
#   'watch',
#   'jace',
#   'slowly',
#   'pull',
#   'shell',
#   'help',
#   'conquer',
#   'fear',
#   'endear',
#   'pain',
#   'real',
#   'deeply',
#   'root',
#   'disappear',
#   'face',
#   'sexiness',
#   'neither',
#   'understandable',
#   'aversion',
#   'marriage',
#   'magically',
#   'disappear',
#   'round',
#   'nookie',
#   'would',
#   'man',
#   'drift',
#   'town',
#   'town',
#   'entire',
#   'adult',
#   'life',
#   'man',
#   'kill',
#   'fair',
#   'share',
#   'men',
#   'along',
#   'way',
#   'feel',
#   'make',
#   'good',
#   'husband',
#   'father',
#   'walk',
#   'wound',
#   'unique',
#   'position',
#   'help',
#   'need',
#   'time',
#   'realize',
#   'however',
#   'pack',
#   'burst',
#   'favorite',
#   'theme',
#   'old',
#   'west',
#   'set',
#   'heroine',
#   'pass',
#   'male',
#   'morally',
#   'ambiguous',
#   'hero',
#   'wound',
#   'souls',
#   'road',
#   'romance',
#   'kitchen',
#   'sink',
#   'certain',
#   'distance',
#   'write',
#   'keep',
#   'get',
#   'carry',
#   'away',
#   'character',
#   'distinct',
#   'fully',
#   'form',
#   'point',
#   'glare',
#   'instance',
#   'bland',
#   'tell',
#   'anything',
#   'never',
#   'felt',
#   'really',
#   'invest',
#   'enjoy',
#   'quite',
#   'bite',
#   'excite',
#   'trip',
#   'watch',
#   'far',
#   'away',
#   'definitely',
#   'run',
#   'alongside',
#   'add',
#   'hasty',
#   'tidy',
#   'end',
#   'book',
#   'leave',
#   'feel',
#   'bite',
#   'less',
#   'completely',
#   'satisfy',
#   'enjoy',
#   'book',
#   'say',
#   'average',
#   'still',
#   'read',
#   'another',
#   'book',
#   'author',
#   'note',
#   'read',
#   'release',
#   'ebook',
#   'version',
#   'notice',
#   'lot',
#   'format',
#   'errors',
#   'miss',
#   'word',
#   'mentally',
#   'edit',
#   'read',
#   'sentence',
#   'make',
#   'sense',
#   'bad',
#   'little',
#   'distract'],
#  ['great',
#   'short',
#   'read',
#   'want',
#   'put',
#   'read',
#   'one',
#   'sit',
#   'sex',
#   'scenes',
#   'great',
#   'two',
#   'males',
#   'one',
#   'female',
#   'character',
#   'bite',
#   'surprise',
#   'never',
#   'think',
#   'could',
#   'learn',
#   'something',
#   'new',
#   'really',
#   'enjoy',
#   'read',
#   'book',
#   'great',
#   'way',
#   'get',
#   'hot',
#   'bother',
#   'take',
#   'advantage',
#   'significant'],
#  ['start',
#   'say',
#   'first',
#   'four',
#   'book',
#   'expect',
#   '34',
#   'conclude',
#   '34',
#   'center',
#   '3',
#   'children',
#   'alex',
#   'younger',
#   'brother',
#   'argus',
#   'alex',
#   'friend',
#   'sapphire',
#   'find',
#   'name',
#   'bus',
#   'map',
#   'find',
#   'mystery',
#   'start',
#   'well',
#   'write',
#   'good',
#   'character',
#   'development',
#   'although',
#   'lot',
#   'room',
#   'still',
#   'quite',
#   'short',
#   'book',
#   'move',
#   'onto',
#   'book',
#   '2',
#   'swiftly'],
#  ['aggie',
#   'angela',
#   'lansbury',
#   'carry',
#   'pocketbooks',
#   'instead',
#   'write',
#   'light',
#   'murder',
#   'mystery',
#   'lace',
#   'misdirections',
#   'clue',
#   'lead',
#   'rather',
#   'obvious',
#   'cliche',
#   'end',
#   'set',
#   'view',
#   'describe',
#   'story',
#   'best',
#   'believable',
#   'part',
#   'aggie',
#   'well',
#   'write',
#   'character',
#   'light',
#   'read'],
#  ['expect', 'type', 'book', 'library', 'please', 'find', 'price', 'right'],
#  ['aislinn',
#   'little',
#   'girl',
#   'big',
#   'dream',
#   'death',
#   'older',
#   'brother',
#   'decide',
#   'follow',
#   'footsteps',
#   'become',
#   'lady',
#   'knight',
#   'quest',
#   'knighthood',
#   'bring',
#   'many',
#   'challenge',
#   'temptation',
#   'forbid',
#   'love',
#   'aislinn',
#   'learn',
#   'knight',
#   'mean',
#   'put',
#   'kingdom',
#   'front',
#   'personal',
#   'concern',
#   'help',
#   'cannot',
#   'help',
#   'journey',
#   'fraught',
#   'danger',
#   'fill',
#   'adventure',
#   'aislinn',
#   'force',
#   'grow',
#   'fast',
#   'must',
#   'stay',
#   'strong',
#   'develop',
#   'skills',
#   'necessary',
#   'realize',
#   'lifelong',
#   'dream',
#   'sword',
#   'fight',
#   'passionate',
#   'love',
#   'mythical',
#   'creatures',
#   'courtly',
#   'game',
#   'woman',
#   'honor',
#   'kind',
#   'book',
#   'love',
#   'idea',
#   'incorporate',
#   'real',
#   'history',
#   'fantasy',
#   'ms',
#   'zoltack',
#   'book',
#   'base',
#   'real',
#   'life',
#   'story',
#   'group',
#   'female',
#   'knight',
#   'blend',
#   'history',
#   'fiction',
#   'write',
#   'full',
#   'plot',
#   'adventure',
#   'character',
#   'strong',
#   'believable',
#   'grow',
#   'love',
#   'care',
#   'hardships',
#   'successes',
#   'aislinn',
#   'quite',
#   'main',
#   'protagonist',
#   'tenacious',
#   'bold',
#   'beautiful',
#   'strong',
#   'romance',
#   'bloom',
#   'prince',
#   'well',
#   'develop',
#   'years',
#   'solid',
#   'friendship',
#   'tease',
#   'enjoy',
#   'read',
#   'secret',
#   'courtship',
#   'idea',
#   'romance',
#   'would',
#   'turn',
#   'ms',
#   'zoltack',
#   'twist',
#   'store',
#   'shock',
#   'startle',
#   'well',
#   'please',
#   'conclusion',
#   'thoroughly',
#   'recommend',
#   'book',
#   'everyone',
#   'enjoy',
#   'fantasy',
#   'romance',
#   'adventure',
#   'eagerly',
#   'await',
#   'sequel',
#   'knight',
#   'glory'],
#  ['makings',
#   'good',
#   'story',
#   'unfortunately',
#   'disappoint',
#   'tell',
#   'two',
#   'alpha',
#   'members',
#   'unfriendly',
#   'pack',
#   'grow',
#   'together',
#   'one',
#   'gay',
#   'straight',
#   'seem',
#   'get',
#   'together',
#   'something',
#   'happen',
#   'story',
#   'tell',
#   'alternate',
#   'chapters',
#   'past',
#   'present',
#   'story',
#   'couple',
#   'fall',
#   'apart',
#   'switch',
#   'time',
#   'lack',
#   'sustainable',
#   'reason',
#   'break'],
#  ['get',
#   'like',
#   'collaborate',
#   'short',
#   'stories',
#   'alot',
#   'time',
#   'two',
#   'good',
#   'writers',
#   'put',
#   'head',
#   'together',
#   'result',
#   'turn',
#   'well',
#   'case',
#   'short',
#   'story',
#   'writers',
#   'take',
#   'age',
#   'old',
#   'lesson',
#   'turn',
#   'good',
#   'read',
#   'begin',
#   'call',
#   'crazy',
#   '1',
#   'pick',
#   'hitchhiker',
#   'get',
#   'graphic',
#   'little',
#   'much',
#   'taste',
#   'cut',
#   'nutcase',
#   '2',
#   'hitchhike',
#   'inevitably',
#   'get',
#   'together',
#   'result',
#   'suspenseful',
#   'end',
#   'felt',
#   'well',
#   'deserve',
#   'account',
#   'also',
#   'watch',
#   'video',
#   'two',
#   'author',
#   'decide',
#   'break',
#   'short',
#   'story',
#   'idea',
#   'cool',
#   'one',
#   'write',
#   'side',
#   'scenario',
#   '1',
#   'scenario',
#   '2',
#   'without',
#   'talk',
#   'tier',
#   'side',
#   'go',
#   'come',
#   'bring',
#   'two',
#   'piece',
#   'together',
#   'make',
#   'fit',
#   'perfectly',
#   'think',
#   'take',
#   'great',
#   'talent',
#   'two',
#   'author',
#   'take',
#   'two',
#   'seperate',
#   'stories',
#   'merge',
#   'well',
#   'story',
#   'pretty',
#   'graphic',
#   'detail',
#   'forwarned',
#   'mind',
#   'little',
#   'detail',
#   'short',
#   'story',
#   'definitely',
#   'pick',
#   'one'],
#  ['love',
#   'book',
#   'hook',
#   'series',
#   'hope',
#   'kelsey',
#   'maxwell',
#   'really',
#   'make',
#   'character',
#   'get',
#   'enough'],
#  ['good',
#   'thing',
#   'short',
#   'sweet',
#   'tease',
#   'give',
#   'everything',
#   'quick',
#   'kick',
#   'kick',
#   'come',
#   'dark'],
#  ['receive',
#   'copy',
#   'book',
#   'review',
#   'secret',
#   'society',
#   'fanatical',
#   'cult',
#   'telepathic',
#   'girl',
#   'cup',
#   'tea',
#   'expect',
#   'really',
#   'need',
#   'another',
#   'continuational',
#   'book',
#   'still',
#   'read',
#   'catch',
#   'fire',
#   'hunger',
#   'game',
#   'get',
#   'sci',
#   'fi',
#   'stuff',
#   'cup',
#   'tea',
#   'sorry'],
#  ['even',
#   'though',
#   'already',
#   'know',
#   'outcome',
#   'still',
#   'enjoyable',
#   'erotic',
#   'read',
#   'little',
#   'short',
#   'taste'],
#  ['read',
#   'review',
#   'decide',
#   'give',
#   'try',
#   'despite',
#   'review',
#   'label',
#   'brutal',
#   'believe',
#   'reviewer',
#   'call',
#   'brutal',
#   'beyond',
#   'disturb',
#   'read',
#   'almost',
#   'anything',
#   'recognize',
#   'fiction',
#   'return',
#   'less',
#   '1',
#   'star',
#   'rat',
#   'available',
#   'would',
#   'use'],
#  ['finish',
#   'read',
#   'wicked',
#   'garden',
#   'say',
#   'wow',
#   'even',
#   'novella',
#   'lorelei',
#   'jam',
#   'write',
#   'stories',
#   'hot',
#   'e',
#   'reader',
#   'start',
#   'smokin',
#   'wicked',
#   'garden',
#   'short',
#   'story',
#   'lose',
#   'love',
#   'reunite',
#   'little',
#   'extra',
#   'sumthin',
#   'sumthin',
#   'billy',
#   'buchanan',
#   'return',
#   'spearfish',
#   'favor',
#   'business',
#   'associate',
#   'agree',
#   'favor',
#   'also',
#   'would',
#   'give',
#   'chance',
#   'ignite',
#   'spark',
#   'high',
#   'school',
#   'flame',
#   'eden',
#   'lacroix',
#   'past',
#   'ten',
#   'years',
#   'regret',
#   'walk',
#   'away',
#   'eden',
#   'eden',
#   'spend',
#   'last',
#   'ten',
#   'years',
#   'build',
#   'career',
#   'dedicate',
#   'local',
#   'community',
#   'center',
#   'help',
#   'risk',
#   'kid',
#   'time',
#   'real',
#   'relationships',
#   'occasional',
#   'string',
#   'attach',
#   'hook',
#   'up',
#   'sexy',
#   'native',
#   'american',
#   'rock',
#   'star',
#   'jon',
#   'white',
#   'feather',
#   'billy',
#   'eden',
#   'see',
#   'first',
#   'time',
#   'ten',
#   'years',
#   'chemistry',
#   'spike',
#   'chart',
#   'eden',
#   'determine',
#   'fight',
#   'billy',
#   'work',
#   'project',
#   'could',
#   'destroy',
#   'job',
#   'quickly',
#   'sweet',
#   'talk',
#   'see',
#   'side',
#   'project',
#   'things',
#   'heat',
#   'eden',
#   'billy',
#   'realize',
#   'still',
#   'strong',
#   'feelings',
#   'dunh',
#   'dunh',
#   'dunh',
#   'jon',
#   'come',
#   'home',
#   'couple',
#   'days',
#   'billy',
#   'jon',
#   'decide',
#   'want',
#   'give',
#   'eden',
#   'one',
#   'darkest',
#   'fantasy',
#   'boy',
#   'boy',
#   'hot',
#   'menage',
#   'really',
#   'like',
#   'eden',
#   'even',
#   'though',
#   'worry',
#   'heart',
#   'billy',
#   'leave',
#   'take',
#   'charge',
#   'sexuality',
#   'scar',
#   'go',
#   'want',
#   'sexually',
#   'much',
#   'like',
#   'eden',
#   'story',
#   'billy',
#   'jon',
#   'steal',
#   'story',
#   'men',
#   'sexy',
#   'strong',
#   'billy',
#   'possessive',
#   'sexy',
#   'dominant',
#   'vulnerable',
#   'absolutely',
#   'adore',
#   'way',
#   'treat',
#   'eden',
#   'insecurities',
#   'display',
#   'jon',
#   'oh',
#   'favorite',
#   'get',
#   'wrong',
#   'love',
#   'billy',
#   'way',
#   'jon',
#   'treat',
#   'eden',
#   'menage',
#   'melt',
#   'heart',
#   'among',
#   'things',
#   'mention',
#   'jon',
#   'sexy',
#   'rock',
#   'star',
#   'moon',
#   'excite',
#   'jon',
#   'get',
#   'novella',
#   'ballroom',
#   'blitz',
#   'release',
#   'date',
#   '10',
#   '2',
#   '12',
#   'folks',
#   'let',
#   'tell',
#   'could',
#   'get',
#   'action',
#   'go',
#   'work',
#   'room',
#   'wicked',
#   'garden',
#   'would',
#   'work',
#   'room',
#   'five',
#   'ten',
#   'time',
#   'day',
#   'wicked',
#   'garden',
#   'great',
#   'novella',
#   'perfect',
#   'afternoon',
#   'want',
#   'escape',
#   'hours',
#   'bonus',
#   'get',
#   'see',
#   'sexy',
#   'lorelei',
#   'write',
#   'non',
#   'cowboys',
#   'yep',
#   'cowboy',
#   'hat',
#   'suit',
#   'ms',
#   'jam',
#   'know',
#   'write',
#   'sexy',
#   'hell',
#   'heroes'],
#  ['king',
#   'jam',
#   'version',
#   'far',
#   'tell',
#   'may',
#   'know',
#   '1611',
#   'kjv',
#   'publish',
#   'book',
#   'include',
#   'get',
#   'ebook',
#   'kjv',
#   'apocrypha',
#   'kindle',
#   'bible',
#   'kjv',
#   'apocrypha',
#   'best',
#   'navigation',
#   'direct',
#   'verse',
#   'jump',
#   'orking',
#   'jam',
#   'bible',
#   'apocryphaorking',
#   'jam',
#   'bible',
#   'apocryphafor',
#   'want',
#   'read',
#   'commentary',
#   'book',
#   'provide',
#   'short',
#   'intros',
#   'misbach',
#   'refer',
#   'either',
#   'halley',
#   'bible',
#   'handbookhalley',
#   'bible',
#   'handbook',
#   'new',
#   'international',
#   'version',
#   'deluxe',
#   'editionor',
#   'new',
#   'unger',
#   'bible',
#   'handbookthe',
#   'new',
#   'unger',
#   'bible',
#   'handbook',
#   'available',
#   'kindle',
#   'ebooks'],
#  ['disappoint',
#   'book',
#   'anything',
#   'blonds',
#   'one',
#   'figure',
#   '500',
#   'joke',
#   'good',
#   'laugh',
#   'wrong',
#   'first',
#   'count',
#   'real',
#   'surprise',
#   'even',
#   '200',
#   'joke',
#   'book',
#   'second',
#   'among',
#   '200',
#   'possible',
#   'joke',
#   'least',
#   '50',
#   'repeat',
#   '2',
#   'time',
#   'different',
#   'part',
#   'book',
#   'almost',
#   'writer',
#   'keep',
#   'run',
#   'list',
#   'joke',
#   'hear',
#   'real',
#   'concern',
#   'whether',
#   'might',
#   'already',
#   'record',
#   'decide',
#   'must',
#   'least',
#   '500',
#   'joke',
#   'finally',
#   'perfectly',
#   'frank',
#   'recall',
#   'laugh',
#   'single',
#   'one',
#   'joke',
#   'better',
#   'describe',
#   'insult',
#   'mistake',
#   'degradation',
#   'group',
#   'people',
#   'humor',
#   '7th',
#   'grade',
#   'material',
#   'bother',
#   'one',
#   'worth',
#   '99',
#   'cents',
#   'even',
#   'worth',
#   'free'],
#  ['super',
#   'quick',
#   'book',
#   'wish',
#   'would',
#   'longer',
#   'really',
#   'like',
#   'character',
#   'sexy',
#   'bedroom',
#   'pool',
#   'table',
#   'sex',
#   'good',
#   'author'],
#  ['many',
#   'time',
#   'author',
#   'go',
#   'get',
#   'amazon',
#   'delete',
#   'add',
#   'comment',
#   'allege',
#   'conspiracies',
#   'people',
#   'get',
#   'f',
#   'delusional',
#   'review',
#   'agree',
#   'previous',
#   'reviewers',
#   'author',
#   'know',
#   'basic',
#   'mechanics',
#   'write',
#   'world',
#   'write',
#   'full',
#   'star',
#   'page',
#   'fill',
#   'grammar',
#   'problems',
#   'story',
#   'suffer',
#   'problems',
#   'author',
#   'inattention',
#   'detail',
#   'character',
#   'inconsistent',
#   'action',
#   'like',
#   'interchangeable',
#   'peg',
#   'board',
#   'author',
#   'put',
#   'place',
#   'need'],
#  ['love',
#   'j',
#   'r',
#   'ward',
#   'book',
#   'story',
#   'completely',
#   'awsome',
#   'zsadist',
#   'favorite',
#   'series'],
#  ['first',
#   'author',
#   'thoroughly',
#   'enjoy',
#   'say',
#   'concept',
#   'dragon',
#   'elves',
#   'djinn',
#   'war',
#   'new',
#   'theres',
#   'usually',
#   'truce',
#   'place',
#   'elves',
#   'djinn',
#   'team',
#   'eliminate',
#   'dragon',
#   'mat',
#   'attempt',
#   'wipe',
#   'dragon',
#   'race',
#   'refresh',
#   'read',
#   'story',
#   'wise',
#   'mean',
#   'scarlet',
#   'pop',
#   'star',
#   'hide',
#   '7',
#   'years',
#   'janos',
#   'dragon',
#   'also',
#   'elder',
#   'scarlet',
#   'mate',
#   'janos',
#   'must',
#   'protect',
#   'till',
#   'impregnate',
#   'accomplish',
#   'change',
#   'thus',
#   'give',
#   'way',
#   'protect',
#   'story',
#   'short',
#   '90',
#   'page',
#   'still',
#   'lot',
#   'tell',
#   'short',
#   'space',
#   'look',
#   'forward',
#   'continue',
#   'saga',
#   'next',
#   'book'],
#  ['first',
#   'anya',
#   'bast',
#   'book',
#   'really',
#   'like',
#   'look',
#   'read',
#   'book',
#   'seem',
#   'little',
#   'far',
#   'fetch',
#   'make',
#   'book',
#   'different',
#   'menage',
#   'stories',
#   'author',
#   'take',
#   'time',
#   'really',
#   'develop',
#   'character',
#   'men',
#   'get',
#   'know',
#   'woman',
#   'claim',
#   'wisk',
#   'screw',
#   'like',
#   'bunnies',
#   '24',
#   '7',
#   'take',
#   'time',
#   'woo',
#   'love',
#   'respect',
#   'honor',
#   'also',
#   'love',
#   'fact',
#   'quite',
#   'ways',
#   'book',
#   'actually',
#   'sex',
#   'great',
#   'read',
#   'one',
#   'would',
#   'highly',
#   'recommend',
#   'would',
#   'love',
#   'action',
#   'intrigue',
#   'part',
#   'love',
#   'hope',
#   'book',
#   'become',
#   'series',
#   'great',
#   'job',
#   'ms',
#   'bast'],
#  ['love',
#   'read',
#   'mini',
#   'novels',
#   'go',
#   'wrong',
#   'jane',
#   'porter',
#   'yet',
#   'another',
#   'great',
#   'read',
#   'amazingly',
#   'talented',
#   'author',
#   'fell',
#   'love',
#   'estrella',
#   'beautiful',
#   'strong',
#   'compassionate',
#   'determine',
#   'carlo',
#   'man',
#   'want',
#   'hate',
#   'instead',
#   'end',
#   'wish',
#   'enjoy',
#   'book',
#   'begin',
#   'end',
#   'character',
#   'personalities',
#   'draw',
#   'story',
#   'line',
#   'make',
#   'want',
#   'reach',
#   'help',
#   'less',
#   'fortunate',
#   'highly',
#   'recommend',
#   'mini',
#   'novel',
#   'perfect',
#   'marriage',
#   'love',
#   'hate',
#   'romance',
#   'philanthropy'],
#  ['book',
#   'extremely',
#   'incredible',
#   'read',
#   'much',
#   'heat',
#   'passion',
#   'describe',
#   'every',
#   'steele',
#   'relationship',
#   'glad',
#   'brothers',
#   'cousin',
#   'find',
#   'passionate',
#   'love',
#   'last'],
#  ['difference',
#   'guy',
#   'man',
#   'willingness',
#   'take',
#   'risk',
#   'relationship',
#   'woman',
#   'course',
#   'hot',
#   'hot',
#   'physical',
#   'attraction',
#   'explosive',
#   'enjoyable',
#   'earn',
#   '3',
#   'star',
#   'genre',
#   'earn',
#   '4th',
#   'star',
#   'quality',
#   'characterization',
#   'interaction',
#   'various',
#   'character',
#   'book',
#   'book',
#   'quick',
#   'short',
#   'read',
#   'right',
#   'palate',
#   'pleaser',
#   'want',
#   'bite',
#   'romance',
#   'sex',
#   'want',
#   'commit'],
#  ['give',
#   'half',
#   'way',
#   'much',
#   'repetition',
#   'much',
#   'make',
#   'sense',
#   'hard',
#   'follow'],
#  ['know',
#   'expect',
#   'way',
#   'form',
#   'fashion',
#   'book',
#   'excite',
#   'think',
#   'order',
#   'wrong',
#   'book',
#   'accident'],
#  ['love',
#   'read',
#   'simon',
#   'wood',
#   'book',
#   'one',
#   'morbid',
#   'make',
#   'reader',
#   'victims',
#   'skin',
#   'crawl',
#   'much',
#   'guess',
#   'outright',
#   'gruesome'],
#  ['short',
#   'story',
#   'confuse',
#   'issue',
#   'unreliable',
#   'narrators',
#   'difficult',
#   'tell',
#   'happen',
#   'story',
#   'write',
#   'poor',
#   'readers',
#   'able',
#   'draw',
#   'conclusions',
#   'virtually',
#   'everybody',
#   'story',
#   'difficulty',
#   'relate',
#   'others',
#   'conversations',
#   'begin',
#   'trail',
#   'without',
#   'important',
#   'information',
#   'relate',
#   'author',
#   'prevent',
#   'normal',
#   'interactions',
#   'us',
#   'able',
#   'judge',
#   'character',
#   'ones',
#   'difficult',
#   'understand',
#   'normal',
#   'human',
#   'interactions',
#   'problem',
#   'actually',
#   'assume',
#   'main',
#   'character',
#   'mentally',
#   'unbalance',
#   'wait',
#   'develop',
#   'throughout',
#   'story',
#   'however',
#   'story',
#   'end',
#   'apparently',
#   'become',
#   'normal',
#   'make',
#   'unfulfilling',
#   'conclusion',
#   'set',
#   'weird',
#   'situation',
#   'short',
#   'story',
#   'foreshadow',
#   'leave',
#   'unexplored',
#   'unexplained',
#   'way',
#   'author',
#   'advance',
#   'story',
#   'tell',
#   'us',
#   'simple',
#   'sentence',
#   'type',
#   'people',
#   'character',
#   'things',
#   'like',
#   'nice',
#   'person',
#   'like',
#   'people',
#   'know',
#   'way',
#   'never',
#   'show',
#   'anything',
#   'action',
#   'story',
#   'people',
#   'put',
#   'situations',
#   'weird',
#   'trail',
#   'conversations',
#   'subject',
#   'basic',
#   'statements',
#   'type',
#   'people',
#   'environment',
#   'realistic',
#   'either',
#   'odd',
#   'word',
#   'think',
#   'first',
#   'maybe',
#   'story',
#   'set',
#   'another',
#   'country',
#   'character',
#   'mention',
#   'michigan',
#   'sense',
#   'place',
#   'get',
#   'story',
#   'know',
#   'michigan',
#   'city',
#   'hope',
#   'anything',
#   'specific',
#   'place',
#   'independent',
#   'office',
#   'supply',
#   'story',
#   'still',
#   'business',
#   'afford',
#   'pay',
#   'ten',
#   'dollars',
#   'hour',
#   'part',
#   'time',
#   'help',
#   'modern',
#   'time',
#   'hope',
#   'anything',
#   'specific',
#   'happen',
#   'character',
#   'seem',
#   'know',
#   'things',
#   'would',
#   'know',
#   'example',
#   'character',
#   'war',
#   'return',
#   'home',
#   'work',
#   'another',
#   'type',
#   'job',
#   'later',
#   'old',
#   'bruise',
#   'face',
#   'think',
#   'character',
#   'war',
#   'however',
#   'human',
#   'heal',
#   'work',
#   'way',
#   'humans',
#   'aware',
#   'bruise',
#   'even',
#   'old',
#   'ones',
#   'relatively',
#   'recent',
#   'old',
#   'trauma',
#   'experience',
#   'read',
#   'story',
#   'kind',
#   'like',
#   'another',
#   'species',
#   'write',
#   'humans',
#   'interactions',
#   'know',
#   'act',
#   'way',
#   'elephant',
#   'interactions',
#   'might',
#   'make',
#   'sense',
#   'proofread',
#   'better',
#   'earlier',
#   'review',
#   'state',
#   'go',
#   'guess',
#   'issue',
#   'correct',
#   'still',
#   'professional',
#   'job'],
#  ['find',
#   'book',
#   'enjoyable',
#   'read',
#   'first',
#   'chapter',
#   'really',
#   'take',
#   'keep',
#   'entertain',
#   'end',
#   'enjoy',
#   'much',
#   'immediately',
#   'purchase',
#   'next',
#   'two',
#   'book',
#   'series'],
#  ['amy',
#   'parker',
#   'go',
#   'hawaii',
#   'week',
#   'christmas',
#   'business',
#   'give',
#   'sex',
#   'relationships',
#   'focus',
#   'career',
#   'justin',
#   'garrett',
#   'travel',
#   'companion',
#   'associate',
#   'law',
#   'firm',
#   'work',
#   'together',
#   'definitely',
#   'plane',
#   'boldly',
#   'masturbate',
#   'seat',
#   'next',
#   'supposedly',
#   'nap',
#   'hear',
#   'everything',
#   'make',
#   'hard',
#   'leave',
#   'trip',
#   'accidentally',
#   'find',
#   'racy',
#   'email',
#   'friend',
#   'laptop',
#   'know',
#   'want',
#   'know',
#   'deepest',
#   'darkest',
#   'desire',
#   'plan',
#   'something',
#   'hawaii',
#   'meet',
#   'client',
#   'mitch',
#   'magruder',
#   'justin',
#   'apprentice',
#   'go',
#   'current',
#   'job',
#   'mitch',
#   'justin',
#   'share',
#   'friendly',
#   'camaraderie',
#   'justin',
#   'know',
#   'count',
#   'mitch',
#   'help',
#   'fulfill',
#   'amy',
#   'fantasy',
#   'two',
#   'work',
#   'get',
#   'amy',
#   'relax',
#   'unwind',
#   'justin',
#   'get',
#   'relax',
#   'enough',
#   'give',
#   'heart',
#   'unwrap',
#   'jaci',
#   'burton',
#   'paint',
#   'vivid',
#   'picture',
#   'two',
#   'men',
#   'coax',
#   'amy',
#   'let',
#   'go',
#   'let',
#   'seduce',
#   'readers',
#   'enjoy',
#   'melt',
#   'hot',
#   'eacute',
#   'nage',
#   'scene',
#   'exquisite',
#   'feel',
#   'finally',
#   'intimate',
#   'someone',
#   'fantasize',
#   'years',
#   'ms',
#   'burton',
#   'book',
#   'power',
#   'pack',
#   'emotion',
#   'sensuality',
#   'love',
#   'style',
#   'create',
#   'believable',
#   'intelligent',
#   'character',
#   'unwrap',
#   'suck',
#   'page',
#   'one',
#   'keep',
#   'rivet',
#   'end',
#   'highly',
#   'recommend',
#   '5',
#   'kiss',
#   '2',
#   'pepper',
#   'f',
#   'eacute',
#   'nage',
#   'anal',
#   'sex',
#   'lindyreviewer',
#   'twolips',
#   'review',
#   'llc'],
#  ['jodi',
#   'birthday',
#   'last',
#   'place',
#   'want',
#   'stick',
#   'work',
#   'boss',
#   'boyfriend',
#   'insist',
#   'night',
#   'job',
#   'complete',
#   'little',
#   'choice',
#   'jodi',
#   'boss',
#   'may',
#   'mattress',
#   'dance',
#   'decide',
#   'early',
#   'would',
#   'string',
#   'attach',
#   'relationship',
#   'lately',
#   'jodi',
#   'second',
#   'thoughts',
#   'relationship',
#   'mark',
#   'sound',
#   'really',
#   'good',
#   'things',
#   'get',
#   'interest',
#   'jodi',
#   'get',
#   'bust',
#   'break',
#   'enter',
#   'sinfully',
#   'sexy',
#   'man',
#   'mark',
#   'rodriguez',
#   'merge',
#   'security',
#   'company',
#   'old',
#   'buddy',
#   'sam',
#   'favor',
#   'ask',
#   'sam',
#   'first',
#   'mark',
#   'would',
#   'like',
#   'sam',
#   'join',
#   'fulfil',
#   'jodi',
#   'eacute',
#   'nage',
#   'fantasy',
#   'birthday',
#   'surprise',
#   'however',
#   'mark',
#   'start',
#   'second',
#   'thoughts',
#   'see',
#   'jodi',
#   'sam',
#   'together',
#   'perhaps',
#   'mark',
#   'want',
#   'jodi',
#   'string',
#   'well',
#   'private',
#   'property',
#   'spicy',
#   'erotic',
#   'novella',
#   'eacute',
#   'nage',
#   'quite',
#   'birthday',
#   'surprise',
#   'jodi',
#   'mark',
#   'jodi',
#   'sam',
#   'heat',
#   'things',
#   'lusty',
#   'novel',
#   'like',
#   'mark',
#   'immediately',
#   'reconsider',
#   'idea',
#   'eacute',
#   'nage',
#   'relationship',
#   'nothing',
#   'like',
#   'see',
#   'woman',
#   'get',
#   'another',
#   'man',
#   'make',
#   'realize',
#   'serious',
#   'private',
#   'property',
#   'leave',
#   'think',
#   'break',
#   'enter',
#   'might',
#   'bad',
#   'thing',
#   'mirandafor',
#   'joyfully',
#   'review'],
#  ['interest',
#   'historic',
#   'value',
#   'really',
#   'story',
#   'rather',
#   'account',
#   'events',
#   'interest',
#   'biographical',
#   'information',
#   '1st',
#   'person'],
#  ['book',
#   'detail',
#   'interest',
#   'felt',
#   'time',
#   'character',
#   'much',
#   'erotic',
#   'get',
#   'bore',
#   'place',
#   'tire',
#   'savannah',
#   'get',
#   'book',
#   'especially',
#   'free',
#   'good',
#   'read'],
#  ['3rd',
#   'book',
#   'second',
#   'time',
#   'still',
#   'good',
#   'excite',
#   'love',
#   'story',
#   'share',
#   'make',
#   'sacrifice',
#   'love',
#   'life',
#   'easy'],
#  ['type',
#   'love',
#   'ghost',
#   'stories',
#   'enjoy',
#   'book',
#   'however',
#   'someone',
#   'else',
#   'may',
#   'enjoy',
#   'never',
#   'let',
#   'people',
#   'opinion',
#   'put',
#   'try',
#   'book',
#   'look',
#   'interest',
#   'say',
#   'kind',
#   'story'],
#  ['believe',
#   'list',
#   'romance',
#   'read',
#   'romance',
#   'novels',
#   'look',
#   'something',
#   'uplift',
#   'book',
#   'dark',
#   'depress',
#   'find',
#   'story',
#   'write',
#   'bad',
#   'depress',
#   'sex',
#   'high',
#   'overview',
#   'go',
#   'depth',
#   'developement',
#   'character',
#   'relationship',
#   'spoiler',
#   'alert',
#   'like',
#   'happy',
#   'end',
#   'forget',
#   'say',
#   'review',
#   'guess',
#   'strongly',
#   'enough',
#   'truly',
#   'understand',
#   'hopefully',
#   'say',
#   'plainly',
#   'enough',
#   'others',
#   'expectations',
#   'waste',
#   'time',
#   'hero',
#   'die',
#   'brutal',
#   'death',
#   'save',
#   'heroine',
#   'book',
#   'continue',
#   'several',
#   'chapters',
#   'show',
#   'remain',
#   'character',
#   'pick',
#   'live',
#   'go',
#   'end',
#   'heroine',
#   'sit',
#   'porch',
#   'contemplate',
#   'life',
#   'wonder',
#   'lie',
#   'ahead',
#   'man',
#   'love',
#   'go',
#   'almost',
#   'cry',
#   'end',
#   'anger',
#   'waste',
#   'free',
#   'time',
#   'read',
#   'book'],
#  ['read',
#   'book',
#   'twice',
#   'make',
#   'sure',
#   'happy',
#   'think',
#   'know',
#   'short',
#   'book',
#   'buy',
#   'actually',
#   'felt',
#   'bad',
#   'finsihed',
#   'story',
#   'line',
#   'great',
#   'charcters',
#   'well',
#   'think',
#   'however',
#   'wish',
#   'longer',
#   'less',
#   'rush',
#   'get',
#   'book',
#   'finish'],
#  ['awesomee',
#   'thriller',
#   'hitch',
#   'begin',
#   'drag',
#   'along',
#   'roller',
#   'coaster',
#   'ride',
#   'way',
#   'end',
#   'book',
#   'great',
#   'twist',
#   'turn',
#   'fell',
#   'inlove',
#   'main',
#   'character',
#   '34',
#   'girlfriend',
#   '34',
#   'highly',
#   'recommend'],
#  ['ok',
#   'story',
#   'think',
#   'character',
#   'little',
#   'shallow',
#   'pull',
#   'bring',
#   'together',
#   'way',
#   'fast',
#   'book',
#   'move',
#   'sexy',
#   'end',
#   'blink',
#   'felt',
#   'like',
#   'chapter',
#   'get',
#   'point',
#   'maybe',
#   'story',
#   'take',
#   'place',
#   'literally',
#   'one',
#   'place',
#   'felt',
#   'like',
#   'really',
#   'room',
#   'growth',
#   'story',
#   'end',
#   'however',
#   'well',
#   'write',
#   'term',
#   'format',
#   'would',
#   'give',
#   'another',
#   'book',
#   'author',
#   'read'],
#  ['great',
#   'twist',
#   'turn',
#   'mystery',
#   'plot',
#   'unable',
#   'stop',
#   'read',
#   'end',
#   'definitely',
#   'must',
#   'read',
#   'mystery',
#   'suspense',
#   'readers',
#   'definitely',
#   'recommend'],
#  ['think',
#   'series',
#   'first',
#   'type',
#   'stories',
#   'see',
#   'jam',
#   'bond',
#   'base',
#   'bulldog',
#   'drummond'],
#  ['book',
#   'wrong',
#   'many',
#   'level',
#   'although',
#   'usually',
#   'type',
#   'spoilers',
#   'one',
#   'hope',
#   'daughter',
#   'one',
#   'scientists',
#   'lab',
#   'wolfe',
#   'hold',
#   'although',
#   'mark',
#   'refuse',
#   'mate',
#   'age',
#   'labs',
#   'burn',
#   'wolfe',
#   'believe',
#   'dead',
#   'years',
#   'hope',
#   'alone',
#   'unable',
#   'move',
#   'another',
#   'man',
#   'bond',
#   'hope',
#   'evil',
#   'mother',
#   'apparently',
#   'know',
#   'wolfe',
#   'survive',
#   'send',
#   'photos',
#   'hope',
#   'men',
#   'fake',
#   'course',
#   'wolfe',
#   'appear',
#   'nowhere',
#   'capture',
#   'hope',
#   'punish',
#   'tease',
#   'sex',
#   'allow',
#   'orgasms',
#   'due',
#   'mat',
#   'heat',
#   'apparently',
#   'writhe',
#   'pain',
#   'continue',
#   'try',
#   'get',
#   'answer',
#   'seek',
#   'find',
#   'nothing',
#   'wrong',
#   'get',
#   'worse',
#   'first',
#   'time',
#   'stick',
#   'ass',
#   'finally',
#   '180',
#   'decide',
#   'innocent',
#   'want',
#   'relieve',
#   'might',
#   'rough',
#   'animal',
#   'surface',
#   'course',
#   'beg',
#   'orgasms',
#   'forgive',
#   'joke',
#   'mother',
#   'show',
#   'quick',
#   'fall',
#   'sandbag',
#   'things',
#   'take',
#   'joke',
#   'write',
#   'even',
#   'good',
#   'sex',
#   'attempt',
#   'story',
#   'throw'],
#  ['stories',
#   'write',
#   'badly',
#   'strike',
#   'emotionally',
#   'tone',
#   'deaf',
#   'fiction',
#   'abuse',
#   'whether',
#   'physical',
#   'emotional',
#   'take',
#   'us',
#   'place',
#   'difficult',
#   'place',
#   'unfamiliar',
#   'maybe',
#   'sadly',
#   'familiar',
#   'story',
#   'find',
#   'think',
#   'people',
#   'act',
#   'way',
#   'think',
#   'way',
#   'things',
#   'little',
#   'pat',
#   'little',
#   'rush',
#   'language',
#   'bite',
#   'careless',
#   'observations',
#   'little',
#   'bite',
#   'hard',
#   'specify',
#   'exactly',
#   'seem',
#   'stories',
#   'almost',
#   'read',
#   'collection',
#   'stories',
#   'write',
#   'somebody',
#   'much',
#   'exposure',
#   'father',
#   'child',
#   'dynamics',
#   'watch',
#   'lifetime',
#   'movie',
#   'marathon'],
#  ['another',
#   'light',
#   'hearted',
#   'novels',
#   'hard',
#   'put',
#   'henry',
#   'wright',
#   'delightful',
#   'character',
#   'get',
#   'tight',
#   'spot'],
#  ['never',
#   'read',
#   'author',
#   'thoroughly',
#   'enjoy',
#   'story',
#   'would',
#   'gladly',
#   'read',
#   'another',
#   'disfigure',
#   'hero',
#   'fear',
#   'pain',
#   'pride',
#   'wonderfully',
#   'describe',
#   'felt',
#   'want',
#   'reach',
#   'gently',
#   'touch',
#   'scar',
#   'reassure',
#   'exactly',
#   'time',
#   'aidan',
#   'touch',
#   'warwick',
#   'get',
#   'wrong',
#   'warwick',
#   'brutally',
#   'strong',
#   'hot',
#   'male',
#   'character',
#   'privy',
#   'thoughts',
#   'within',
#   'story',
#   'begin',
#   'get',
#   'protective',
#   'feelings',
#   'aidan',
#   'acquire',
#   'saw',
#   'extremely',
#   'handsome',
#   'man',
#   'warwick',
#   'really',
#   'passion',
#   'romace',
#   'well',
#   'mix',
#   'much',
#   'strengh',
#   'wit',
#   'character',
#   'sometimes',
#   'sure',
#   'real',
#   'hero',
#   'story',
#   'everyone',
#   'like',
#   'strong',
#   'take',
#   'matter',
#   'hand',
#   'heroines',
#   'definately',
#   'book',
#   'one',
#   'woman',
#   'rescue',
#   'squad',
#   'perfect',
#   'match',
#   'mysterious',
#   'mask',
#   'hire',
#   'guard',
#   'warwick',
#   'sex',
#   'hot',
#   'wicked',
#   'well',
#   'enjoy'],
#  ['book',
#   'deserve',
#   'winner',
#   'prestigious',
#   'giller',
#   'prize',
#   '2008',
#   'want',
#   'read',
#   'time',
#   'want',
#   'read',
#   'boyden',
#   'first',
#   'book',
#   'three',
#   'day',
#   'road',
#   'first',
#   'good',
#   'book',
#   'one',
#   'even',
#   'better',
#   'good',
#   'read',
#   'three',
#   'day',
#   'road',
#   'first',
#   'precursor',
#   'one',
#   'help',
#   'understand',
#   'character',
#   'bite',
#   'like',
#   'three',
#   'day',
#   'road',
#   'book',
#   'difficult',
#   'read',
#   'ways',
#   'keep',
#   'wait',
#   'terrible',
#   'cataclysmic',
#   'thing',
#   'happen',
#   'even',
#   'though',
#   'know',
#   'go',
#   'happen',
#   'make',
#   'less',
#   'terrible',
#   'book',
#   'also',
#   'similar',
#   'three',
#   'day',
#   'road',
#   'tell',
#   'viewpoints',
#   'two',
#   'different',
#   'people',
#   'young',
#   'niece',
#   'annie',
#   'terrible',
#   'stories',
#   'tell',
#   'heal',
#   'share',
#   'highly',
#   'recommend',
#   'book',
#   'would',
#   'suggest',
#   'read',
#   'three',
#   'day',
#   'road',
#   'first',
#   'feel',
#   'richer',
#   'experience',
#   'enjoy',
#   'superlative',
#   'story',
#   'tell',
#   'book',
#   'take',
#   'everyday',
#   'life',
#   'magical',
#   'world',
#   'seem',
#   'real',
#   'read'],
#  ['amazon',
#   'curse',
#   'build',
#   'relationships',
#   'events',
#   'develop',
#   'vampire',
#   'bride',
#   'showalter',
#   'book',
#   'stand',
#   'alone',
#   'much',
#   'better',
#   'know',
#   'back',
#   'story',
#   'rat',
#   'would',
#   'different',
#   'already',
#   'connect',
#   'character',
#   'read',
#   'previous',
#   'book',
#   'vampire',
#   'bride',
#   'focus',
#   'layel',
#   'king',
#   'vampires',
#   'delilah',
#   'amazon',
#   'warrior',
#   'however',
#   'introduce',
#   'many',
#   'character',
#   'include',
#   'zane',
#   'nola',
#   'happy',
#   'find',
#   'story',
#   'end',
#   'would',
#   'suggest',
#   'use',
#   'book',
#   'alone',
#   'introduction',
#   'showalter',
#   'write',
#   'miss'],
#  ['fan',
#   'bind',
#   'hearts',
#   'series',
#   'perhaps',
#   'best',
#   'review',
#   'book',
#   'try',
#   'two',
#   'since',
#   'reader',
#   'romantic',
#   'book',
#   'see',
#   'much',
#   'romance',
#   '34',
#   'share',
#   '34'],
#  ['stop',
#   'read',
#   'series',
#   'love',
#   'character',
#   'jacob',
#   'especially',
#   'victor',
#   'relationship',
#   'well',
#   'plot',
#   'always',
#   'good',
#   'bite',
#   'mystery',
#   'go',
#   'adventure',
#   'get',
#   'know',
#   'victor',
#   'past',
#   'voice',
#   'usual',
#   'something',
#   'look',
#   'forward'],
#  ['love',
#   'series',
#   'see',
#   'stories',
#   'family',
#   'members',
#   'together',
#   'convenient',
#   'best'],
#  ['like',
#   'dragons',
#   'free',
#   'download',
#   'give',
#   'try',
#   'aside',
#   'need',
#   'edit',
#   'least',
#   'proofread',
#   'clear',
#   'clunky',
#   'storytelling',
#   'find',
#   'disappoint',
#   'story',
#   'start',
#   'slow',
#   'work',
#   'unevenly',
#   'burst',
#   'action',
#   'end',
#   'conclusion',
#   'blue',
#   'jump',
#   'premise',
#   'dragonseer',
#   'saga',
#   'series',
#   'halfway',
#   'download',
#   'half',
#   'turn',
#   'preview',
#   'first',
#   'full',
#   'length',
#   'dragoneers',
#   'book',
#   'even',
#   'know',
#   'prequel',
#   'even',
#   'know',
#   'novella',
#   'hop',
#   'complete',
#   'self',
#   'contain',
#   'tale',
#   'amount',
#   'overlong',
#   'prologue',
#   'bother',
#   'preview',
#   'novella',
#   'accurate',
#   'indicator',
#   'author',
#   'style',
#   'sense',
#   'story',
#   'already',
#   'know',
#   'dragonseer',
#   'saga',
#   'read',
#   'list',
#   'anytime',
#   'soon'],
#  ['first',
#   'book',
#   'watchers',
#   'series',
#   'intrigue',
#   'fascinate',
#   'vampire',
#   'world',
#   'escape',
#   'years',
#   'abuse',
#   'prisoner',
#   'brutal',
#   'drug',
#   'lord',
#   'robyn',
#   'andrews',
#   'board',
#   'first',
#   'bus',
#   'town',
#   'head',
#   'louisville',
#   'kentucky',
#   'chance',
#   'encounter',
#   'stranger',
#   'change',
#   'life',
#   'better',
#   'watchers',
#   'one',
#   'mission',
#   'life',
#   'hunt',
#   'eliminate',
#   'rogue',
#   'vampires',
#   'trigg',
#   'want',
#   'leave',
#   'alone',
#   'job',
#   '8217',
#   'seem',
#   'harden',
#   'heart',
#   'petite',
#   'woman',
#   'look',
#   'lose',
#   'stand',
#   'rain',
#   'know',
#   'future',
#   'impossible',
#   '8217',
#   'human',
#   '8217',
#   'vampire',
#   '8217',
#   'someone',
#   'special',
#   'past',
#   'catch',
#   'way',
#   'change',
#   'destinies',
#   'steady',
#   'fast',
#   'pace',
#   'plot',
#   'keep',
#   'reader',
#   'engage',
#   'begin',
#   'end',
#   'well',
#   'write',
#   'scenes',
#   'vivid',
#   'image',
#   'great',
#   'compel',
#   'character',
#   'author',
#   'fantastic',
#   'job',
#   'give',
#   'character',
#   'life',
#   'reader',
#   '8217',
#   'help',
#   'become',
#   'enamor',
#   'want',
#   'know',
#   'reader',
#   'get',
#   'catch',
#   'live',
#   'trigg',
#   'robyn',
#   'sweep',
#   'along',
#   'watchers',
#   'missions',
#   'battle',
#   'rogues',
#   'get',
#   'adrenalin',
#   'pump',
#   'attraction',
#   'trigg',
#   'robyn',
#   'sweet',
#   'passion',
#   'burn',
#   'super',
#   'hot',
#   'time',
#   'author',
#   'convey',
#   'chemistry',
#   'relationship',
#   'intensity',
#   'capture',
#   'imagination',
#   'reader',
#   '8217',
#   'help',
#   'feel',
#   'two',
#   'character',
#   'robyn',
#   '8217',
#   'strong',
#   'sweet',
#   'person',
#   'hell',
#   'trigg',
#   'tough',
#   'vampire',
#   'tender',
#   'feelings',
#   'lose',
#   'waif',
#   'reader',
#   'fall',
#   'love',
#   'even',
#   'sex',
#   'scenes',
#   'contradictory',
#   'fact',
#   'sweet',
#   'tender',
#   'carry',
#   'away',
#   'hot',
#   'steamy',
#   'lust',
#   'take',
#   'reader',
#   '8217',
#   'breath',
#   'away',
#   '8217',
#   'wait',
#   'read',
#   'next',
#   'book',
#   'wonderful',
#   'entertain',
#   'vampire',
#   'world',
#   'vane',
#   'rosa',
#   'rayne',
#   'definitely',
#   'catch',
#   'attention',
#   'want',
#   'know',
#   'well',
#   'watchers'],
#  ['mexican',
#   'heat',
#   'crimes',
#   'cocktails',
#   'shrug',
#   'good',
#   'predictable',
#   'read',
#   'like',
#   'laura',
#   'baumbach',
#   'josh',
#   'lanyon',
#   'one',
#   'favorites'],
#  ['book',
#   'complete',
#   'waste',
#   '2',
#   'mention',
#   'time',
#   'spend',
#   'try',
#   'read',
#   'bad',
#   'story',
#   'line',
#   'potential',
#   'bunch',
#   'poorly',
#   'write',
#   'drivel',
#   'redundancy',
#   'speech',
#   'book',
#   'wow',
#   'book',
#   'write',
#   'many',
#   'point',
#   'view',
#   'hard',
#   'tell',
#   'speak',
#   'get',
#   'wrong',
#   'know',
#   'romance',
#   'novel',
#   'c',
#   'mon',
#   'look',
#   'like',
#   'one',
#   'think',
#   'book',
#   'horrible',
#   'apologize',
#   'warn',
#   'away',
#   'book',
#   'horribly',
#   'sappy',
#   'sugary',
#   'kind',
#   'read',
#   'think',
#   'actually',
#   'gain',
#   '5',
#   'lbs',
#   'couple',
#   'cavities',
#   'read',
#   'get'],
#  ['write',
#   'downer',
#   'review',
#   'yesterday',
#   'realize',
#   'read',
#   'entire',
#   'book',
#   'silly',
#   'good',
#   'cookbook',
#   'clear',
#   'directions',
#   'quite',
#   'bite',
#   'good',
#   'help',
#   'basic',
#   'kindle',
#   'user',
#   'guide',
#   'know',
#   'fun',
#   'new',
#   'best',
#   'friend',
#   'mine',
#   'finish',
#   'cookbook',
#   'start',
#   'try',
#   'things',
#   'list',
#   'one',
#   'think',
#   'able',
#   'access',
#   'gmail',
#   'go',
#   'road',
#   'rv',
#   'make',
#   'mouth',
#   'water',
#   'add',
#   'ease',
#   'read',
#   'larger',
#   'type',
#   'well',
#   'western',
#   'reader',
#   'one',
#   'happy',
#   'gal',
#   'thank',
#   'david',
#   'hard',
#   'work'],
#  ['know',
#   'download',
#   'get',
#   'first',
#   'couple',
#   'chapters',
#   'read',
#   'delete',
#   'psycho',
#   'stuff'],
#  ['jt',
#   'summer',
#   'trouble',
#   'lust',
#   'friends',
#   'little',
#   'sister',
#   'happy',
#   'suppose',
#   'protector',
#   'would',
#   'save',
#   'nikki',
#   'durant',
#   'know',
#   'want',
#   'like',
#   'know',
#   'equally',
#   'affect',
#   'nikki',
#   'get',
#   'arrest',
#   'near',
#   'jt',
#   'resist',
#   'pull',
#   'stop',
#   'go',
#   'friend',
#   'jasmine',
#   'help',
#   'jt',
#   'arrive',
#   'sweetwater',
#   'ranch',
#   'take',
#   'jasmine',
#   'swim',
#   'invite',
#   'horrify',
#   'find',
#   'nikki',
#   'sunbathe',
#   'nude',
#   'know',
#   'moment',
#   'erotic',
#   'encounter',
#   'jt',
#   'get',
#   'nikki',
#   'mind',
#   'show',
#   'office',
#   'rainstorm',
#   'start',
#   'strip',
#   'office',
#   'know',
#   'deep',
#   'way',
#   'could',
#   'resist',
#   'even',
#   'try',
#   'first',
#   'encounter',
#   'realize',
#   'take',
#   'virginity',
#   'call',
#   'easy',
#   'whore',
#   'jt',
#   'know',
#   'even',
#   'name',
#   'badly',
#   'screw',
#   'nikki',
#   'save',
#   'treat',
#   'horribly',
#   'try',
#   'see',
#   'jasmine',
#   'seth',
#   'zane',
#   'prevent',
#   'get',
#   'anywhere',
#   'near',
#   'know',
#   'late',
#   'figure',
#   'love',
#   'go',
#   'win',
#   'back',
#   'another',
#   'winner',
#   'mb',
#   'like',
#   'nikki',
#   'brash',
#   'sassy',
#   'go',
#   'want',
#   'full',
#   'steam',
#   'half',
#   'way',
#   'jt',
#   'fight',
#   'love',
#   'nikki',
#   'overwhelm',
#   'obligation',
#   'promise',
#   'make',
#   'brother',
#   'jt',
#   'promise',
#   'protect',
#   'brother',
#   'absence',
#   'love',
#   'instead',
#   'great',
#   'read'],
#  ['good',
#   'book',
#   'easy',
#   'read',
#   'ms',
#   'lennox',
#   'write',
#   'good',
#   'stories',
#   'need',
#   'love',
#   'story',
#   'rainy',
#   'beach',
#   'day'],
#  ['reviewers',
#   'right',
#   'money',
#   'point',
#   'book',
#   'could',
#   'benefit',
#   'tremendously',
#   'quality',
#   'edit',
#   'particularly',
#   'editor',
#   'sense',
#   'tell',
#   'author',
#   'write',
#   'quirk',
#   'patently',
#   'ridiculous',
#   'main',
#   'character',
#   'first',
#   'last',
#   'name',
#   'use',
#   'nearly',
#   'every',
#   'time',
#   'mention',
#   'call',
#   'first',
#   'last',
#   'name',
#   'almost',
#   'often',
#   'intend',
#   'cute',
#   'mannerism',
#   'work',
#   'large',
#   'portion',
#   'book',
#   'completely',
#   'unrealistic',
#   'disjoint',
#   'even',
#   'book',
#   'one',
#   'automatically',
#   'approach',
#   'certain',
#   'level',
#   'suspend',
#   'belief',
#   'character',
#   'potential',
#   'never',
#   'live',
#   'small',
#   'part',
#   'actually',
#   'find',
#   'ark',
#   'interest',
#   'also',
#   'completely',
#   'fail',
#   'live',
#   'potential',
#   'surprisingly',
#   'brief',
#   'largely',
#   'ignore',
#   'rest',
#   'book',
#   'despite',
#   'supposedly',
#   'center',
#   'story',
#   'finish',
#   'book',
#   'read',
#   'anything',
#   'else',
#   'author',
#   'suggest',
#   'readers',
#   'waste',
#   'time'],
#  ['enjoy', 'novel', 'much', 'book', 'enjoy', 'author', 'read', 'book'],
#  ['draw',
#   'story',
#   'find',
#   'unbelievable',
#   'feel',
#   'main',
#   'character',
#   'still',
#   'thank',
#   'author',
#   'offer',
#   'book',
#   'free'],
#  ['story',
#   'start',
#   'story',
#   'start',
#   'queen',
#   'many',
#   'traitors',
#   'midst',
#   'guy',
#   'top',
#   'list',
#   'quickly',
#   'seduce',
#   'bore',
#   'quick',
#   'sex',
#   'romp',
#   'story',
#   'story',
#   'take',
#   '7',
#   'minutes',
#   'excerpt',
#   'countless',
#   'stories',
#   'want',
#   'buy',
#   'take',
#   'much',
#   'longer',
#   'book'],
#  ['first',
#   'admit',
#   'finish',
#   'book',
#   'write',
#   'terrible',
#   'place',
#   'hard',
#   'time',
#   'try',
#   'figure',
#   'heck',
#   'go',
#   'book',
#   'really',
#   'weird',
#   'take',
#   'long',
#   'h',
#   'h',
#   'even',
#   'meet',
#   'seem',
#   'force',
#   'read',
#   'customer',
#   'review',
#   'purchase',
#   'good',
#   'things',
#   'say',
#   'versus',
#   'bad',
#   'figure',
#   'would',
#   'give',
#   'whirl',
#   'big',
#   'mistake',
#   'lose',
#   '99',
#   'cents',
#   'hours',
#   'life',
#   'never',
#   'get',
#   'back',
#   'skip'],
#  ['much',
#   'paranormal',
#   'romance',
#   'novels',
#   'must',
#   'say',
#   'caleb',
#   'man',
#   'man',
#   'know',
#   'want',
#   'go',
#   'get',
#   'case',
#   'want',
#   'sommer',
#   'boy',
#   'get',
#   'good',
#   'read'],
#  ['quinn',
#   'libby',
#   'mckay',
#   'together',
#   'fourteen',
#   'years',
#   'last',
#   'three',
#   'months',
#   'libby',
#   'live',
#   'kick',
#   'husband',
#   'go',
#   'way',
#   'roommates',
#   'decide',
#   'either',
#   'shake',
#   'things',
#   'let',
#   'go',
#   'move',
#   'truly',
#   'shock',
#   'seem',
#   'take',
#   'stride',
#   'saw',
#   'dance',
#   'someone',
#   'else',
#   'one',
#   'night',
#   'ziggy',
#   'quinn',
#   'lose',
#   'temper',
#   'give',
#   'hope',
#   'walk',
#   'away',
#   'want',
#   'cause',
#   'scene',
#   'ready',
#   'give',
#   'quinn',
#   'show',
#   'library',
#   'wait',
#   'car',
#   'libby',
#   'know',
#   'think',
#   'hear',
#   'ask',
#   'second',
#   'chance',
#   'proposition',
#   'spend',
#   'weekend',
#   'alone',
#   'know',
#   'think',
#   'libby',
#   'surprise',
#   'hear',
#   'agreement',
#   'would',
#   'give',
#   'time',
#   'think',
#   'time',
#   'together',
#   'uninterrupted',
#   'free',
#   'pressure',
#   'far',
#   'apart',
#   'past',
#   'year',
#   'libby',
#   'afraid',
#   'get',
#   'hop',
#   'know',
#   'last',
#   'chance',
#   'skeptically',
#   'agree',
#   'different',
#   'spin',
#   'witness',
#   'demise',
#   'good',
#   'marriage',
#   'two',
#   'basically',
#   'kind',
#   'hearted',
#   'people',
#   'allow',
#   'issue',
#   'come',
#   'instead',
#   'tackle',
#   'head',
#   'try',
#   'deal',
#   'alone',
#   'separate',
#   'farther',
#   'two',
#   'find',
#   'path',
#   'back',
#   'good',
#   'read',
#   'strong',
#   'character',
#   'rough',
#   'rider',
#   'readers',
#   'appreciate',
#   'story'],
#  ['never',
#   'underestimate',
#   'mind',
#   'unrehabilitated',
#   'criminal',
#   'especially',
#   'one',
#   'plan',
#   'next',
#   'violent',
#   'crime',
#   'complete',
#   'latest',
#   'jail',
#   'sentence',
#   'simply',
#   'put',
#   'final',
#   'lesson',
#   'life',
#   'final',
#   'crime',
#   'thank',
#   'amazon',
#   'able',
#   'purchase',
#   'book',
#   'along',
#   '50',
#   'others',
#   'far',
#   'reasonable',
#   'cost',
#   'convenience',
#   'without',
#   'read',
#   'material',
#   'since',
#   'receive',
#   'kindle'],
#  ['enjoy',
#   'begin',
#   'part',
#   'book',
#   'last',
#   'third',
#   'spoilers',
#   'get',
#   'really',
#   'frustrate',
#   'romance',
#   'book',
#   'either',
#   'h',
#   'h',
#   'decide',
#   'good',
#   'enough',
#   'however',
#   'book',
#   'first',
#   'half',
#   'h',
#   'felt',
#   'good',
#   'enough',
#   'second',
#   'half',
#   'h',
#   'plus',
#   'issue',
#   'bite',
#   'much',
#   'waver',
#   'intimate',
#   'relationship',
#   'would',
#   'like',
#   'see',
#   'commitment',
#   'realistic',
#   'time',
#   'period'],
#  ['friday',
#   'night',
#   'hailey',
#   'jennison',
#   'join',
#   'friends',
#   'even',
#   'group',
#   'voyeurism',
#   'hunk',
#   'across',
#   'way',
#   'friend',
#   'apartment',
#   'strut',
#   'stuff',
#   'place',
#   'time',
#   'get',
#   'catch',
#   'hailey',
#   'one',
#   'bear',
#   'gage',
#   'punishment',
#   'choice',
#   'even',
#   'ok',
#   'gage',
#   'admit',
#   'blackmail',
#   'wait',
#   'months',
#   'chance',
#   'get',
#   'beautiful',
#   'skittish',
#   'hailey',
#   'go',
#   'opportunity',
#   'come',
#   'grab',
#   'much',
#   'like',
#   'like',
#   'grab',
#   'never',
#   'blackmail',
#   'look',
#   'dang',
#   'good',
#   'marie',
#   'harte',
#   'newest',
#   'release',
#   'samhain',
#   'publish',
#   'enjoy',
#   'show',
#   'leave',
#   'wonder',
#   'take',
#   'voyeurism',
#   'hobby',
#   'neighbor',
#   'like',
#   'gage',
#   'warren',
#   'think',
#   'might',
#   'work',
#   'well',
#   'hailey',
#   'loldespite',
#   'blackmail',
#   'gage',
#   'certainly',
#   'never',
#   'force',
#   'hailey',
#   'anything',
#   'want',
#   'fact',
#   'go',
#   'way',
#   'leave',
#   'choices',
#   'need',
#   'realize',
#   'much',
#   'care',
#   'temporary',
#   'sexual',
#   'fling',
#   'real',
#   'relationship',
#   'although',
#   'trust',
#   'gage',
#   'hailey',
#   'nevertheless',
#   'slow',
#   'trust',
#   'feelings',
#   'anything',
#   'transient',
#   'get',
#   'attention',
#   'really',
#   'great',
#   'sex',
#   'gage',
#   'easily',
#   'win',
#   'heart',
#   'unending',
#   'patience',
#   'ways',
#   'show',
#   'much',
#   'mean',
#   'person',
#   'friend',
#   'instead',
#   'bed',
#   'partner',
#   'every',
#   'time',
#   'read',
#   'another',
#   'marie',
#   'harte',
#   'story',
#   'become',
#   'bigger',
#   'fan',
#   'talented',
#   'author',
#   'holiday',
#   'sure',
#   'splurge',
#   'backlist',
#   'enjoy',
#   'show',
#   'great',
#   'addition',
#   'erotic',
#   'romance',
#   'library',
#   'certain',
#   'leave',
#   'keep',
#   'eye',
#   'hunk',
#   'view'],
#  ['great',
#   'begin',
#   'fun',
#   'spicy',
#   'series',
#   'keil',
#   'definition',
#   'possessive',
#   'alpha',
#   'male',
#   'story',
#   'love',
#   'read',
#   'keil',
#   'robyn',
#   'work',
#   'communication',
#   'issue',
#   'turn',
#   'story',
#   'one',
#   'never',
#   'read',
#   'recommend',
#   'book',
#   'series',
#   'anyone',
#   'like',
#   'read',
#   'werewolf',
#   'slightly',
#   'erotic',
#   'romance',
#   'review',
#   'book',
#   'review',
#   'read',
#   'review',
#   'get',
#   'teaser',
#   'blog'],
#  ['short',
#   'story',
#   'entirely',
#   'short',
#   'unable',
#   'figure',
#   'purpose',
#   'page',
#   'could',
#   'incorporate',
#   'another',
#   'book',
#   'series',
#   'disappoint'],
#  ['good',
#   'short',
#   'story',
#   'reasonable',
#   'price',
#   'reviewers',
#   'provide',
#   'story',
#   'line',
#   'add',
#   'like',
#   'mctark',
#   'inventiveness',
#   'sex',
#   'scenes',
#   'tinge',
#   'exhibitionism',
#   'good',
#   'chemistry',
#   'brian',
#   'amber',
#   'character',
#   'enough',
#   'depth',
#   'make',
#   'care',
#   'misunderstand',
#   'little',
#   'character',
#   'brian',
#   'gotta',
#   'angst',
#   'tension',
#   'good',
#   'story',
#   'could',
#   'use',
#   'little',
#   'background',
#   'brian',
#   'nice',
#   'hot',
#   'hunky',
#   'hang',
#   'guy',
#   'like',
#   'brian',
#   'marry',
#   'least',
#   'involve'],
#  ['really',
#   'enjoy',
#   'book',
#   'different',
#   'read',
#   'actually',
#   'use',
#   'older',
#   'cha',
#   'r',
#   'cater',
#   'make',
#   'book',
#   'great',
#   'humor',
#   'make',
#   'laugh'],
#  ['irony',
#   'absolutely',
#   'kill',
#   'product',
#   'get',
#   'free',
#   'book',
#   'pay',
#   'con',
#   'check',
#   'help',
#   'page',
#   'people',
#   'review',
#   'save',
#   'money'],
#  ['first',
#   'book',
#   'read',
#   'lady',
#   'good',
#   'shall',
#   'order',
#   'another',
#   'one',
#   'soon'],
#  ['big',
#   'book',
#   'sell',
#   'government',
#   'pretty',
#   'extensive',
#   'novice',
#   'technical',
#   'silver',
#   'grant',
#   'ok',
#   '3',
#   'star'],
#  ['quick',
#   'read',
#   'fun',
#   'story',
#   'enjoy',
#   'character',
#   'simple',
#   'story',
#   'line',
#   'perfect',
#   'book',
#   'vacation'],
#  ['love',
#   'book',
#   'rock',
#   'star',
#   'find',
#   'jump',
#   'joke',
#   'definitely',
#   'story',
#   'potential',
#   'great',
#   'read',
#   'felt',
#   'like',
#   'waste',
#   'time',
#   'read',
#   'like',
#   'rush',
#   'completion',
#   'areas',
#   'character',
#   'severly',
#   'develop',
#   'areas',
#   'give',
#   'way',
#   'much',
#   'detail',
#   'would',
#   'love',
#   'see',
#   'rewrite',
#   'give',
#   'true',
#   'chance',
#   'capture',
#   'us',
#   'rock',
#   'star',
#   'book',
#   'love',
#   'praise'],
#  ['great',
#   'story',
#   'love',
#   '3',
#   'chapters',
#   'wish',
#   'entire',
#   'book',
#   'could',
#   'get',
#   'background',
#   'whys',
#   '2',
#   'main',
#   'character',
#   'wonder',
#   'one',
#   'star',
#   'reviewers',
#   'expect',
#   'mean',
#   'name',
#   'imply',
#   'serial',
#   'killers',
#   'blurb',
#   'right',
#   'target',
#   'course',
#   'gruesome',
#   'disturb',
#   'sick',
#   'geez',
#   'reviewers',
#   'review',
#   'peter',
#   'pan',
#   'give',
#   '1',
#   'star',
#   'kid',
#   'book',
#   'pretty',
#   'ridiculous',
#   'rate',
#   'book',
#   'low',
#   'fit',
#   'genre'],
#  ['mr',
#   'simon',
#   'story',
#   'coachella',
#   'valley',
#   'traffic',
#   'jam',
#   'really',
#   'best',
#   'character',
# ...
#   'write',
#   'science',
#   'fiction',
#   '15',
#   'years',
#   'attract',
#   'real',
#   'notice',
#   'last',
#   'paratime',
#   'story',
#   'lord',
#   'kalvin',
#   'otherwhen',
#   'unrelated',
#   'little',
#   'fuzzy',
#   'unfortunately',
#   'depress',
#   'financial',
#   'trouble',
#   'commit',
#   'suicide',
#   'career',
#   'take',
#   'good',
#   'collection',
#   'help',
#   'remember',
#   'h',
#   'beam',
#   'piper',
#   'best'],
#  ['first',
#   'time',
#   'read',
#   'author',
#   'really',
#   'go',
#   'detail',
#   'character',
#   'history',
#   'india',
#   'read',
#   'stories',
#   'series',
#   'especially',
#   'one',
#   'heroine',
#   'sister',
#   'best',
#   'destroy',
#   'sister',
#   'romance',
#   'like',
#   'last',
#   'book',
#   'better',
#   'ash',
#   'really',
#   'become',
#   'couple',
#   'marry',
#   'glad',
#   'end',
#   'speak',
#   'lie',
#   'rumor',
#   'tell',
#   'allow',
#   'keep',
#   'life',
#   'want'],
#  ['big',
#   'improvement',
#   'management',
#   'skills',
#   'scenes',
#   'play',
#   'completely',
#   'nice',
#   'quick',
#   'read',
#   'happy',
#   'bri',
#   'finally',
#   'get',
#   'hea'],
#  ['book',
#   'hilarious',
#   'person',
#   'staff',
#   'psychocat',
#   'oscar',
#   'find',
#   'answer',
#   'mine',
#   'way',
#   'wonder',
#   'think',
#   'things',
#   'max',
#   'question',
#   'one',
#   'us',
#   'really',
#   'need',
#   'therapy',
#   'cat',
#   'max',
#   'oscar',
#   'make',
#   'wonder',
#   'one',
#   'obviously',
#   'train',
#   'right',
#   'way',
#   'especially',
#   'feed',
#   'demand',
#   'cater',
#   'every',
#   'whim',
#   'think',
#   'clue',
#   'work',
#   'mind',
#   'cat',
#   'hope'],
#  ['awesome',
#   'novella',
#   'may',
#   'little',
#   'bias',
#   'z',
#   'bella',
#   'favorite',
#   'ugh',
#   'pretty',
#   'awesome',
#   'bella',
#   'baby',
#   'beautiful',
#   'girl',
#   'name',
#   'nalla',
#   'course',
#   'z',
#   'scar',
#   'labor',
#   'know',
#   'possible',
#   'lose',
#   'bella',
#   'baby',
#   'pull',
#   'wrong',
#   'z',
#   'touch',
#   'pick',
#   'even',
#   'look',
#   'daughter',
#   'keep',
#   'distance',
#   'call',
#   'nalla',
#   'bella',
#   'daughter',
#   'claim',
#   'talk',
#   'family',
#   'keep',
#   'say',
#   'young',
#   'child',
#   'etc',
#   'heartbreaking',
#   'finally',
#   'bella',
#   'take',
#   'anymore',
#   'need',
#   'decide',
#   'want',
#   'bella',
#   'say',
#   'father',
#   'leave',
#   'know',
#   'sound',
#   'harsh',
#   'think',
#   'best',
#   'love',
#   'always',
#   'love',
#   'anymore',
#   'hurt',
#   'heart',
#   'z',
#   'go',
#   'mission',
#   'end',
#   'hurt',
#   'think',
#   'bella',
#   'get',
#   'back',
#   'bella',
#   'come',
#   'learn',
#   'wrong',
#   'learn',
#   'pull',
#   'away',
#   'past',
#   'still',
#   'much',
#   'part',
#   'afraid',
#   'daughter',
#   'suffer',
#   'really',
#   'good',
#   'short',
#   'read',
#   'bdb',
#   'fan'],
#  ['start',
#   'read',
#   'series',
#   'actually',
#   'start',
#   'bear',
#   'necessities',
#   'love',
#   'read',
#   'better',
#   'order',
#   'problem',
#   'find',
#   'correct',
#   'order',
#   'book',
#   '2',
#   'halle',
#   'pumas',
#   'halle',
#   'shifters',
#   'lead',
#   'series',
#   'ok',
#   'saw',
#   'review',
#   '1',
#   'star',
#   'book',
#   'dull',
#   'feel',
#   'way',
#   'ask',
#   'short',
#   'book',
#   'fool',
#   '4000',
#   'line',
#   'last',
#   'third',
#   'book',
#   'sypnosis',
#   'book',
#   'actually',
#   'read',
#   '3',
#   'one',
#   'day',
#   'stretch',
#   'stories',
#   'engage',
#   'women',
#   'kick',
#   'dialogue',
#   'funny',
#   'basically',
#   'shifter',
#   'see',
#   'meet',
#   'smell',
#   'hear',
#   'mate',
#   'mate',
#   'human',
#   'one',
#   'bite',
#   'start',
#   'conversion',
#   'shifters',
#   'diverse',
#   'inter',
#   'marry',
#   'species',
#   'main',
#   'rule',
#   'let',
#   'humans',
#   'know',
#   'apparently',
#   'work',
#   'well',
#   'halle',
#   'lot',
#   'carry',
#   'one',
#   'book',
#   'next',
#   'meet',
#   'new',
#   'character',
#   'revisit',
#   'old',
#   'character',
#   'book',
#   'becky',
#   'human',
#   'crush',
#   'simon',
#   'puma',
#   'make',
#   'bear',
#   'since',
#   'high',
#   'school',
#   'simon',
#   'date',
#   'one',
#   'town',
#   'snotty',
#   'women',
#   'since',
#   'high',
#   'school',
#   'never',
#   'really',
#   'notice',
#   'becky',
#   'attack',
#   'jealous',
#   'puma',
#   'come',
#   'rescue',
#   'realize',
#   'mate',
#   'mean',
#   'easy',
#   'like',
#   'series',
#   'shifter',
#   'series',
#   'read',
#   'dark',
#   'serious',
#   'like'],
#  ['sure',
#   'someone',
#   'like',
#   'one',
#   'guess',
#   'get',
#   'pay',
#   'waste',
#   'money',
#   'time'],
#  ['good',
#   'easy',
#   'read',
#   'full',
#   'every',
#   'emotion',
#   'could',
#   'think',
#   'live',
#   'loss',
#   'hate',
#   'forgiveness',
#   'gonna',
#   'lie',
#   'pull',
#   'heart',
#   'string',
#   'rear',
#   'wish',
#   'epilogue'],
#  ['never',
#   'realize',
#   'fairy',
#   'tales',
#   'hear',
#   'life',
#   'base',
#   'horrible',
#   'tales',
#   'think',
#   'good',
#   'book',
#   'hand',
#   'grandchildren',
#   'would',
#   'read',
#   'allow',
#   'read'],
#  ['completely',
#   'unrealistic',
#   'oh',
#   'gosh',
#   'hot',
#   'real',
#   'way',
#   'like',
#   'something',
#   'middle',
#   'age',
#   'woman',
#   'would',
#   'think',
#   'lunch',
#   'break',
#   'ideal',
#   'romance',
#   'middle',
#   'age',
#   'woman',
#   'try',
#   'pass',
#   'lunch',
#   'break',
#   'daydream',
#   'professional',
#   'quality',
#   'short',
#   'stories',
#   'anyway',
#   'kayla',
#   'think',
#   'old',
#   'find',
#   'true',
#   'love',
#   'perfect',
#   'hot',
#   'sensitive',
#   'guy',
#   'right',
#   'front',
#   'whole',
#   'time',
#   'think',
#   'super',
#   'sexy',
#   'want',
#   'perfect',
#   'rough',
#   'yet',
#   'tender',
#   'lover',
#   'new',
#   'job',
#   'separate',
#   'suspense',
#   'suspenseful',
#   'sex',
#   'scenes',
#   'hot',
#   'skip',
#   'one'],
#  ['great',
#   'read',
#   'really',
#   'glad',
#   'download',
#   'want',
#   'put',
#   'would',
#   'recommend',
#   'read',
#   'mysterious',
#   'island'],
#  ['first', 'half', 'good', 'short', 'stories', 'jack', 'daniels', 'like'],
#  ['breed',
#   'next',
#   'door',
#   'lora',
#   'leigh',
#   'short',
#   'story',
#   'revolve',
#   'around',
#   'lyra',
#   'tarek',
#   'short',
#   'story',
#   'well',
#   'write',
#   'leave',
#   'want',
#   'whole',
#   'story',
#   'base',
#   'two',
#   'character',
#   'lyra',
#   'give',
#   'tarek',
#   'hell',
#   'every',
#   'chance',
#   'get',
#   'ever',
#   'since',
#   'become',
#   'neighbor',
#   'would',
#   'like',
#   'think',
#   'things',
#   'wrong',
#   'every',
#   'time',
#   'talk',
#   'get',
#   'hot',
#   'someone',
#   'try',
#   'break',
#   'apartment',
#   'normal',
#   'b',
#   'e',
#   'robbers',
#   'get',
#   'even',
#   'question',
#   'savior',
#   'tarek',
#   'tarek',
#   'mission',
#   'suppose',
#   'look',
#   'one',
#   'lab',
#   'scientists',
#   'get',
#   'away',
#   'past',
#   'couple',
#   'months',
#   'find',
#   'save',
#   'lyra',
#   'attack',
#   'house',
#   'realize',
#   'scientist',
#   'breed',
#   'next',
#   'door',
#   'fun',
#   'excite',
#   'read',
#   'leave',
#   'want',
#   'moreash'],
#  ['big',
#   'kahuna',
#   'newspapers',
#   'deliver',
#   'right',
#   'kindle',
#   'even',
#   'need',
#   'get',
#   'bed',
#   'throne',
#   'retrieve',
#   'soggy',
#   'paper',
#   'version',
#   'snow',
#   'yard',
#   'read',
#   'right',
#   'beloved',
#   'kindle',
#   'problem',
#   'high',
#   'price',
#   'get',
#   'pesky',
#   'drm',
#   'content',
#   'put',
#   'kindle',
#   'content',
#   'like',
#   'evil',
#   'drm',
#   'inherent',
#   'kindle',
#   'let',
#   'view',
#   'content',
#   'kindle',
#   'print',
#   'article',
#   'email',
#   'article',
#   'friend',
#   'use',
#   'presentations',
#   'stick',
#   'evil',
#   'live',
#   'price',
#   'restrictions',
#   'drm',
#   'go',
#   'friend'],
#  ['want',
#   'hymn',
#   'music',
#   'word',
#   'help',
#   'much',
#   'help',
#   'word',
#   'thank',
#   'dale'],
#  ['read',
#   'pnr',
#   'years',
#   'usually',
#   'devour',
#   'book',
#   'day',
#   'one',
#   'take',
#   'week',
#   'horrible',
#   'good',
#   'either',
#   'something',
#   'think',
#   'biggest',
#   'problem',
#   'h',
#   'seem',
#   'piss',
#   'sure',
#   'attitude',
#   'kidnap',
#   'come',
#   'accept',
#   'life',
#   'guess',
#   'come',
#   'bitchy',
#   'whole',
#   'book',
#   'good',
#   'way',
#   'also',
#   'think',
#   'toward',
#   'end',
#   'book',
#   'skip',
#   'several',
#   'months',
#   'years',
#   'whole',
#   'someone',
#   'try',
#   'kill',
#   'take',
#   'back',
#   'seat',
#   'whole',
#   'book',
#   'resolve',
#   'matter',
#   'page',
#   'end',
#   'sex',
#   'little',
#   'bore',
#   'except',
#   'whole',
#   'ryan',
#   'phillip',
#   'scene',
#   'hot',
#   'book',
#   'worst',
#   'ever',
#   'read',
#   'definitely',
#   'worth',
#   'money',
#   'pay'],
#  ['wary',
#   'read',
#   'book',
#   'never',
#   'read',
#   'well',
#   'write',
#   'creative',
#   'classic',
#   'really',
#   'sink',
#   'depths',
#   'earth',
#   'charactors',
#   'time',
#   'would',
#   'hold',
#   'breath',
#   'think',
#   'wait',
#   'lolhe',
#   'think',
#   'lot',
#   'write',
#   'book',
#   'would',
#   'really',
#   'go',
#   'earth',
#   'three',
#   'men',
#   'climb',
#   'dormit',
#   'volcano',
#   'start',
#   'journey',
#   'find',
#   'center',
#   'earth',
#   'experience',
#   'see',
#   'depths',
#   'amaze',
#   'imagination',
#   'giants',
#   'sea',
#   'creatures',
#   'world',
#   'underneath',
#   'return',
#   'surface',
#   'earth',
#   'truly',
#   'amaze',
#   'journey'],
#  ['finish',
#   'story',
#   'quite',
#   'grip',
#   'guess',
#   'perhaps',
#   'pace',
#   'facebooking',
#   'really',
#   'care',
#   'get',
#   'back',
#   'together',
#   'mean',
#   'really',
#   'move',
#   'away',
#   'way',
#   'decide',
#   'notice',
#   'begin',
#   'seem',
#   'stupid',
#   'story',
#   'flash',
#   'forward',
#   'past',
#   'entire',
#   'relationship',
#   'breakup',
#   'past',
#   'fail',
#   'marriage',
#   'try',
#   'contact',
#   'via',
#   'social',
#   'media',
#   'say',
#   'give',
#   'whiplash',
#   'would',
#   'suggest',
#   'move',
#   'end',
#   'author',
#   'fail',
#   'make',
#   'care'],
#  ['ok',
#   'prepare',
#   'chick',
#   'light',
#   'ready',
#   'another',
#   'dumb',
#   'romance',
#   'treatment',
#   'character',
#   'things',
#   'etc',
#   'especially',
#   'shallow',
#   'cannot',
#   'forgive',
#   'however',
#   'misuse',
#   'word',
#   'book',
#   'writers',
#   'need',
#   'use',
#   'spellcheck',
#   'find',
#   'need',
#   'actually',
#   'read',
#   'book',
#   'start',
#   'show',
#   '75',
#   'reason',
#   'writer',
#   'get',
#   'hurry',
#   'finish',
#   'book',
#   'perhaps',
#   'sick',
#   'unforgivable',
#   'peace',
#   'pieceshuttered',
#   'shudderedsaver',
#   'savorknow',
#   'nowsummons',
#   'summon',
#   'set',
#   'look',
#   'errors',
#   'jump',
#   'page',
#   'bad',
#   'disrupt',
#   'entire',
#   'think',
#   'process',
#   'run',
#   'across',
#   'stupid',
#   'errors',
#   'like',
#   'glad',
#   'pay',
#   'book',
#   'worth',
#   'money',
#   'read',
#   'anything',
#   'author',
#   'day',
#   'age',
#   'everyone',
#   'seem',
#   'think',
#   'write',
#   'book',
#   'easy',
#   'write',
#   'good',
#   'book',
#   'suggest',
#   'writer',
#   'read',
#   'good',
#   'book',
#   'figure',
#   'stuff',
#   'tripe',
#   'author',
#   'need',
#   'take',
#   'english',
#   '101',
#   'mistake',
#   'unforgivable',
#   'anyone',
#   'purport',
#   'writer',
#   'high',
#   'school',
#   'student',
#   'could',
#   'write',
#   'something',
#   'like',
#   'perhaps'],
#  ['wait',
#   'read',
#   'next',
#   'book',
#   'love',
#   'character',
#   'place',
#   'rancho',
#   'mirage',
#   'ca',
#   'fun',
#   'read',
#   'book',
#   'also',
#   'friend',
#   'cabin',
#   'twain',
#   'harte',
#   'real',
#   'kick',
#   'would',
#   'recommend',
#   'albert',
#   'simon',
#   'henry',
#   'wright',
#   'mysteries'],
#  ['docia',
#   'cal',
#   'wed',
#   'back',
#   'drop',
#   'pete',
#   'janie',
#   'romance',
#   'wed',
#   'hell',
#   'drama',
#   'expect',
#   'plus',
#   'still',
#   'full',
#   'character',
#   'love',
#   'love',
#   'love',
#   'hate',
#   'plus',
#   'nice',
#   'plot',
#   'twist',
#   'keep',
#   'guess',
#   'anxious',
#   'moments',
#   'last',
#   'long',
#   'overall',
#   'fun',
#   'read',
#   'give',
#   'benjamin',
#   'prop',
#   'create',
#   'female',
#   'villain',
#   'love',
#   'hate',
#   'first',
#   'book',
#   'grant',
#   'want',
#   'flatten',
#   'meteor',
#   'slap',
#   'silly',
#   'airplane',
#   'like',
#   'line',
#   'character',
#   'comuppence',
#   'adequate',
#   'five',
#   'star',
#   'highly',
#   'recommend',
#   'fun',
#   'quirky',
#   'character',
#   'cute',
#   'pet',
#   'top',
#   'small',
#   'town',
#   'texas',
#   'make',
#   'book',
#   'pure',
#   'joy',
#   'read'],
#  ['claire',
#   'hold',
#   'usual',
#   'seat',
#   'corner',
#   'new',
#   'year',
#   'eve',
#   'party',
#   'people',
#   'watch',
#   'make',
#   'note',
#   'erotic',
#   'romance',
#   'write',
#   'notice',
#   'really',
#   'hot',
#   'guy',
#   'cause',
#   'excite',
#   'fantasy',
#   'realize',
#   'another',
#   'hot',
#   'guy',
#   'come',
#   'way',
#   'look',
#   'around',
#   'see',
#   'come',
#   'see',
#   'cannot',
#   'former',
#   'geeks',
#   'high',
#   'school',
#   'mason',
#   'hunter',
#   'party',
#   'see',
#   'claire',
#   'hear',
#   'mason',
#   'associate',
#   'paul',
#   'claire',
#   'go',
#   'high',
#   'school',
#   'change',
#   'still',
#   'watch',
#   'life',
#   'happen',
#   'around',
#   'shy',
#   'look',
#   'past',
#   '10',
#   'years',
#   'crush',
#   'want',
#   'see',
#   'still',
#   'exist',
#   'lucky',
#   'claire',
#   'since',
#   'claire',
#   'make',
#   'new',
#   'years',
#   'resolutions',
#   'figure',
#   'might',
#   'well',
#   'go',
#   'agree',
#   'join',
#   'mason',
#   'hunter',
#   'overnight',
#   'eacute',
#   'nage',
#   'least',
#   'reason',
#   'give',
#   'delightful',
#   'romance',
#   'include',
#   'threesome',
#   'affair',
#   'may',
#   'lead',
#   'character',
#   'vivid',
#   'storyline',
#   'well',
#   'do',
#   'even',
#   'though',
#   'short',
#   'story',
#   'like',
#   'background',
#   'character',
#   'know',
#   'even',
#   'though',
#   'best',
#   'friends',
#   'enjoyable',
#   'read'],
#  ['decide',
#   'read',
#   'book',
#   'free',
#   'read',
#   'things',
#   'lora',
#   'leigh',
#   'never',
#   'read',
#   'bind',
#   'hearts',
#   'desire',
#   'read',
#   'another',
#   'spoiler',
#   'tess',
#   'call',
#   'father',
#   'ask',
#   'come',
#   'party',
#   'one',
#   'year',
#   'agree',
#   'come',
#   'week',
#   'mother',
#   'father',
#   'divorce',
#   'could',
#   'deal',
#   'kinky',
#   'life',
#   'style',
#   'marry',
#   'dumb',
#   'blond',
#   'ten',
#   'years',
#   'older',
#   'tess',
#   'like',
#   'thing',
#   'brother',
#   'tell',
#   'two',
#   'years',
#   'ago',
#   'sexual',
#   'things',
#   'would',
#   'like',
#   'see',
#   'since',
#   'read',
#   'book',
#   'college',
#   'mother',
#   'call',
#   'pervert',
#   'reason',
#   'story',
#   'hear',
#   'cole',
#   'ask',
#   'party',
#   'pleasuring',
#   'self',
#   'hear',
#   'two',
#   'years',
#   'go',
#   'father',
#   'missy',
#   'suppose',
#   'come',
#   'back',
#   'next',
#   'day',
#   'except',
#   'cole',
#   'come',
#   'find',
#   'father',
#   'get',
#   'cole',
#   'teach',
#   'submissive',
#   'wake',
#   'next',
#   'day',
#   'tie',
#   'spread',
#   'eagle',
#   'tell',
#   'say',
#   'never',
#   'stop',
#   'ask',
#   'bring',
#   'another',
#   'man',
#   'work',
#   'father',
#   'well',
#   'cole',
#   'threesome',
#   'far',
#   'love',
#   'foreplay',
#   'cole',
#   'want',
#   'three',
#   'bed',
#   'walk',
#   'mother',
#   'scream',
#   'pervert',
#   'father',
#   'step',
#   'mother',
#   'man',
#   'leave',
#   'say',
#   'involed',
#   'tess',
#   'go',
#   'kitchen',
#   'hat',
#   'step',
#   'mother',
#   'eat',
#   'ice',
#   'cream',
#   'friends',
#   'cole',
#   'disappear',
#   'leave',
#   'end',
#   'seem',
#   'real',
#   'could',
#   'get',
#   'father',
#   'set',
#   'plus',
#   'man',
#   'romance',
#   'ever',
#   'like',
#   'bondage',
#   'story',
#   'deal',
#   'maybe',
#   'tie',
#   'fun',
#   'blue',
#   'moon',
#   'see',
#   'someone',
#   'else',
#   'tell',
#   'like',
#   'think',
#   'devil',
#   'beat',
#   'change',
#   'see',
#   'feel',
#   'pain',
#   'heavy',
#   'stuff',
#   'thing',
#   'say',
#   'good',
#   'would',
#   'give',
#   'one',
#   'star',
#   'one',
#   'lora',
#   'leigh',
#   'write',
#   'better',
#   'book'],
#  ['book',
#   'full',
#   'gems',
#   'like',
#   'sentence',
#   'use',
#   'incorrectly',
#   'much',
#   'start',
#   'read',
#   'loud',
#   'funnier',
#   'way',
#   'teacher',
#   'editor',
#   'believe',
#   'book',
#   'drive',
#   'insane',
#   'story',
#   'interest',
#   'get',
#   'odd',
#   'place',
#   'pop',
#   'story',
#   'hope',
#   'make',
#   'laugh',
#   'great',
#   'book',
#   'read',
#   'party',
#   'game',
#   'everyone',
#   'take',
#   'shoot',
#   'come',
#   'across',
#   'word',
#   'use',
#   'incorrectly',
#   'warn',
#   'people',
#   'mind',
#   'sleep',
#   'place',
#   'cause',
#   'one',
#   'fit',
#   'drive',
#   'second',
#   'page',
#   'see',
#   'wrong',
#   'sentence',
#   'use',
#   'title',
#   'review',
#   'please',
#   'find',
#   'english',
#   'teachers',
#   'slap',
#   'smile',
#   'back',
#   'eyebrow',
#   'lift',
#   'smile',
#   'back',
#   'eyebrow',
#   'lift',
#   'eyebrow',
#   'lift',
#   'smile',
#   'back',
#   'name',
#   'underneath',
#   'cry',
#   'editor',
#   'story',
#   'truly',
#   'potential'],
#  ['story',
#   'old',
#   'fashion',
#   'feel',
#   'sometimes',
#   'story',
#   'get',
#   'bite',
#   'slow',
#   'like',
#   'main',
#   'character',
#   'strength',
#   'determination',
#   'find',
#   'happen',
#   'husband',
#   'admirable',
#   'book',
#   'mix',
#   'bite',
#   'mystery',
#   'crime',
#   'investigation',
#   'political',
#   'cover',
#   'magic',
#   'together'],
#  ...]

# %%
import gensim
w2v_model = gensim.models.Word2Vec(lemmatized_word, epochs=100, vector_size=100)

# %%
w2v_model.wv.index_to_key
# Out:
# ['book',
#  'read',
#  'story',
#  'like',
#  'one',
#  'character',
#  'get',
#  'love',
#  'good',
#  'would',
#  'really',
#  'time',
#  'make',
#  'author',
#  'write',
#  'go',
#  'think',
#  'find',
#  'want',
#  'know',
#  'series',
#  'well',
#  'end',
#  'enjoy',
#  'much',
#  'first',
#  'even',
#  'give',
#  'short',
#  'take',
#  'great',
#  'could',
#  'sex',
#  'little',
#  'say',
#  'way',
#  'interest',
#  'two',
#  'see',
#  'plot',
#  'come',
#  'romance',
#  'also',
#  'keep',
#  'work',
#  'look',
#  'start',
#  'seem',
#  'stories',
#  'feel',
#  'never',
#  'need',
#  'review',
#  'kindle',
#  'try',
#  'life',
#  'many',
#  'lot',
#  'bite',
#  'leave',
#  'another',
#  'better',
#  'star',
#  'man',
#  'hot',
#  'tell',
#  'still',
#  'back',
#  'though',
#  'enough',
#  'recommend',
#  'people',
#  'happen',
#  'use',
#  'part',
#  'page',
#  'something',
#  'free',
#  'bad',
#  'things',
#  '34',
#  'world',
#  'new',
#  'together',
#  'scenes',
#  'put',
#  'next',
#  'turn',
#  'woman',
#  'felt',
#  'years',
#  'buy',
#  'best',
#  'finish',
#  'novel',
#  'word',
#  'thing',
#  'begin',
#  'live',
#  'relationship',
#  'guy',
#  'main',
#  'long',
#  'however',
#  'line',
#  'help',
#  'fun',
#  'since',
#  'point',
#  'meet',
#  'hard',
#  '2',
#  'set',
#  'right',
#  'real',
#  'become',
#  'sure',
#  'different',
#  'without',
#  'nothing',
#  'let',
#  'ever',
#  'expect',
#  'every',
#  'action',
#  'reader',
#  'anything',
#  'always',
#  'family',
#  'men',
#  'definitely',
#  'place',
#  'old',
#  'worth',
#  'actually',
#  'three',
#  '3',
#  'heroine',
#  'pretty',
#  'around',
#  'quite',
#  'hero',
#  'wait',
#  'believe',
#  'whole',
#  'mean',
#  'lose',
#  'second',
#  'away',
#  'sexy',
#  'nice',
#  'show',
#  'disappoint',
#  'might',
#  'fact',
#  '5',
#  'wish',
#  'understand',
#  'someone',
#  'develop',
#  'do',
#  'far',
#  'friend',
#  'issue',
#  'mind',
#  'care',
#  'call',
#  'may',
#  'almost',
#  '1',
#  'day',
#  'kind',
#  'couple',
#  'yet',
#  'change',
#  'follow',
#  'reason',
#  'last',
#  'maybe',
#  'move',
#  'detail',
#  'everything',
#  'decide',
#  'quick',
#  'full',
#  'past',
#  'idea',
#  'novella',
#  'stop',
#  'scene',
#  'friends',
#  'fantasy',
#  'fall',
#  'strong',
#  'father',
#  'bring',
#  'others',
#  'job',
#  'mystery',
#  'spend',
#  'must',
#  '4',
#  'miss',
#  'development',
#  'least',
#  'night',
#  'lead',
#  'pick',
#  'lack',
#  'realize',
#  'erotic',
#  'fan',
#  'sweet',
#  'fast',
#  'although',
#  'anyone',
#  'add',
#  'girl',
#  'happy',
#  'home',
#  'learn',
#  'run',
#  'bore',
#  'surprise',
#  'easy',
#  'sense',
#  'especially',
#  'able',
#  'overall',
#  'money',
#  'big',
#  'pay',
#  'name',
#  'forward',
#  'waste',
#  'price',
#  'young',
#  'women',
#  'style',
#  'sexual',
#  'readers',
#  'person',
#  'hold',
#  'type',
#  'continue',
#  'talk',
#  'probably',
#  'kill',
#  'build',
#  'high',
#  'year',
#  'twist',
#  'order',
#  'true',
#  'cover',
#  'writer',
#  'instead',
#  'wrong',
#  'vampire',
#  'hope',
#  'else',
#  'case',
#  'edit',
#  'along',
#  'rather',
#  'storyline',
#  'less',
#  'brother',
#  'download',
#  'marry',
#  'us',
#  'rest',
#  'longer',
#  'wonderful',
#  'several',
#  'include',
#  'mate',
#  'break',
#  'problem',
#  'side',
#  'ok',
#  'force',
#  'light',
#  'ms',
#  'heart',
#  'draw',
#  'either',
#  'fight',
#  'guess',
#  'finally',
#  '8217',
#  'later',
#  'deal',
#  'feelings',
#  'perfect',
#  'stand',
#  'half',
#  'husband',
#  'enjoyable',
#  'completely',
#  'course',
#  'glad',
#  'male',
#  'novels',
#  'tale',
#  'entertain',
#  'favorite',
#  'describe',
#  'female',
#  'future',
#  'head',
#  'experience',
#  'fiction',
#  'figure',
#  'alpha',
#  'eye',
#  'play',
#  'quickly',
#  'okay',
#  'everyone',
#  'save',
#  'purchase',
#  'pack',
#  'wonder',
#  'hop',
#  'chapter',
#  'mention',
#  'amazon',
#  'pace',
#  'errors',
#  'ask',
#  'human',
#  'wife',
#  'premise',
#  'believable',
#  'yes',
#  'already',
#  'stay',
#  'title',
#  'attention',
#  'throw',
#  'hand',
#  'h',
#  'steamy',
#  'mother',
#  'highly',
#  'rat',
#  'age',
#  'plan',
#  'chance',
#  'length',
#  'entire',
#  'description',
#  'funny',
#  'truly',
#  'involve',
#  'create',
#  'school',
#  'sometimes',
#  'grow',
#  'suppose',
#  'town',
#  'dark',
#  'share',
#  'paranormal',
#  'sorry',
#  'sort',
#  'face',
#  'dream',
#  'open',
#  'list',
#  'dialogue',
#  'house',
#  'offer',
#  'oh',
#  'totally',
#  'war',
#  'romantic',
#  'consider',
#  'confuse',
#  'intrigue',
#  'alone',
#  'self',
#  'erotica',
#  'genre',
#  'language',
#  'catch',
#  'depth',
#  'unfortunately',
#  'ago',
#  'matter',
#  'soon',
#  'usually',
#  'sister',
#  'complete',
#  'problems',
#  'potential',
#  'version',
#  'touch',
#  'bother',
#  'die',
#  'annoy',
#  'base',
#  'throughout',
#  'mat',
#  'watch',
#  'remember',
#  'murder',
#  'wolf',
#  'present',
#  'discover',
#  'top',
#  'chapters',
#  'explain',
#  'agree',
#  'gay',
#  'date',
#  'return',
#  'days',
#  'sound',
#  'act',
#  'adventure',
#  'absolutely',
#  'slow',
#  'simply',
#  'publish',
#  'check',
#  'poor',
#  'skip',
#  'format',
#  'often',
#  'fill',
#  'question',
#  'excite',
#  'difficult',
#  'thank',
#  'death',
#  'humor',
#  'small',
#  'close',
#  'third',
#  'history',
#  'note',
#  'bed',
#  'introduce',
#  'certainly',
#  'please',
#  'accept',
#  'excellent',
#  'four',
#  'perhaps',
#  'kid',
#  'desire',
#  'easily',
#  'suspense',
#  'collection',
#  'opinion',
#  'engage',
#  'five',
#  'amaze',
#  'child',
#  'pass',
#  'allow',
#  'sentence',
#  'boy',
#  'heat',
#  'mistake',
#  'power',
#  'jump',
#  'group',
#  'brothers',
#  'vampires',
#  'pull',
#  'across',
#  'laugh',
#  'cute',
#  'admit',
#  'form',
#  'speak',
#  'hear',
#  'flow',
#  'information',
#  'cause',
#  'promise',
#  'tales',
#  'children',
#  'mark',
#  'beautiful',
#  'attraction',
#  'background',
#  'provide',
#  'stuff',
#  '99',
#  'trouble',
#  'trust',
#  'rush',
#  'control',
#  'body',
#  'middle',
#  'satisfy',
#  'hate',
#  'marriage',
#  'etc',
#  'lover',
#  'predictable',
#  'choose',
#  'fit',
#  'alex',
#  'level',
#  'seriously',
#  'extremely',
#  'within',
#  'ex',
#  'manage',
#  'content',
#  'descriptions',
#  'struggle',
#  'beyond',
#  'behind',
#  'focus',
#  'view',
#  'jam',
#  'appear',
#  'magic',
#  'soul',
#  'will',
#  'werewolf',
#  'situation',
#  'hook',
#  'emotional',
#  'immediately',
#  'business',
#  'conflict',
#  'hurt',
#  'room',
#  'son',
#  'daughter',
#  'warn',
#  'early',
#  'attempt',
#  'number',
#  'science',
#  'sit',
#  'picture',
#  'ones',
#  'christmas',
#  'e',
#  'forget',
#  'saw',
#  'exactly',
#  'chemistry',
#  'clear',
#  'original',
#  'fell',
#  'secret',
#  'due',
#  'dead',
#  'important',
#  'protect',
#  'hide',
#  'space',
#  'send',
#  'state',
#  'ways',
#  'partner',
#  'despite',
#  'contain',
#  'concept',
#  'cannot',
#  'taste',
#  'huge',
#  'walk',
#  'months',
#  '10',
#  'moment',
#  'hours',
#  'mr',
#  'editor',
#  'appreciate',
#  'somewhat',
#  'fine',
#  'realistic',
#  'simple',
#  'special',
#  'ready',
#  'black',
#  'imagine',
#  'god',
#  'treat',
#  'previous',
#  'piece',
#  'step',
#  'drive',
#  'example',
#  'bdsm',
#  'earth',
#  'fear',
#  'weak',
#  'older',
#  'f',
#  'movie',
#  'convince',
#  'spell',
#  'except',
#  'unique',
#  'mostly',
#  'theme',
#  'tension',
#  'mix',
#  'evil',
#  'hell',
#  'basically',
#  'events',
#  'serial',
#  'personal',
#  'hunter',
#  'receive',
#  'anyway',
#  'decent',
#  'plus',
#  'claim',
#  'serious',
#  'hit',
#  'none',
#  'grammar',
#  'boyfriend',
#  'connection',
#  'strange',
#  'passion',
#  'lady',
#  'stupid',
#  'escape',
#  'paragraph',
#  'fi',
#  'fairly',
#  'sci',
#  'kate',
#  'super',
#  'encounter',
#  'suggest',
#  'blood',
#  'relate',
#  'shifter',
#  'straight',
#  'certain',
#  'crazy',
#  'upon',
#  'non',
#  'honest',
#  'comment',
#  'parent',
#  'fairy',
#  'determine',
#  'copy',
#  'paper',
#  'single',
#  'spoilers',
#  'lie',
#  'master',
#  'sequel',
#  'lust',
#  'game',
#  'humans',
#  'christian',
#  'amount',
#  'post',
#  'police',
#  'sad',
#  'graphic',
#  'blake',
#  'relationships',
#  'alien',
#  'ghost',
#  'blog',
#  'travel',
#  'stick',
#  'sleep',
#  'choice',
#  'drama',
#  'historical',
#  'cat',
#  'notice',
#  'dragon',
#  'horror',
#  'major',
#  'hat',
#  'menage',
#  'connect',
#  'honestly',
#  'baby',
#  'survive',
#  'grab',
#  'jane',
#  'sample',
#  'available',
#  'adult',
#  'thoroughly',
#  'push',
#  'term',
#  'handle',
#  'killer',
#  'neither',
#  'club',
#  'fire',
#  'king',
#  'unless',
#  'particularly',
#  'nature',
#  'wed',
#  'knight',
#  'normally',
#  'solve',
#  'flat',
#  'awesome',
#  'cut',
#  'whether',
#  'john',
#  'typos',
#  'delete',
#  'emotions',
#  'poorly',
#  'concern',
#  'worst',
#  'car',
#  'kidnap',
#  'land',
#  'deliver',
#  'max',
#  'fully',
#  'near',
#  'research',
#  'reviewer',
#  'possible',
#  '6',
#  'horrible',
#  'prefer',
#  'deserve',
#  'reveal',
#  'train',
#  'deep',
#  'trilogy',
#  'answer',
#  'eacute',
#  'lord',
#  'situations',
#  'fail',
#  'ridiculous',
#  'reviewers',
#  'typical',
#  'moments',
#  'race',
#  'appeal',
#  'bond',
#  'joyfully',
#  'kelly',
#  'suddenly',
#  'thoughts',
#  'visit',
#  'shock',
#  'modern',
#  'fantastic',
#  'charge',
#  'silly',
#  'edge',
#  'otherwise',
#  'attack',
#  'spoiler',
#  'wow',
#  'kiss',
#  'result',
#  'unbelievable',
#  'voice',
#  'actual',
#  'subject',
#  'search',
#  'tie',
#  'sell',
#  'feature',
#  'jake',
#  'minutes',
#  'happily',
#  'win',
#  'prequel',
#  'apparently',
#  'week',
#  'quality',
#  'thriller',
#  'emma',
#  'shoot',
#  'tear',
#  'prove',
#  'distract',
#  'battle',
#  'drop',
#  'print',
#  'classic',
#  'attract',
#  'suffer',
#  'worse',
#  'reality',
#  'odd',
#  'ability',
#  'reference',
#  'capture',
#  'simon',
#  'hea',
#  'plenty',
#  'slave',
#  'english',
#  'basic',
#  'truth',
#  'jack',
#  'article',
#  'cry',
#  'cop',
#  'yeah',
#  'hang',
#  'count',
#  'pain',
#  'reach',
#  'carry',
#  'demons',
#  'charm',
#  'west',
#  'ruin',
#  'ship',
#  'lovers',
#  'kaylee',
#  'rape',
#  'edition',
#  'shift',
#  'hunt',
#  'today',
#  'weird',
#  'party',
#  'particular',
#  'remind',
#  'violence',
#  'journey',
#  '20',
#  'company',
#  'danger',
#  'rescue',
#  'pleasure',
#  'late',
#  'mysteries',
#  'respect',
#  'doubt',
#  'afraid',
#  'familiar',
#  'rich',
#  'nearly',
#  'regard',
#  'apart',
#  'drag',
#  'remain',
#  'j',
#  'detective',
#  'trip',
#  'red',
#  'ebook',
#  'forever',
#  'ideas',
#  'literally',
#  'writers',
#  'aspect',
#  'eventually',
#  'obviously',
#  'normal',
#  'witch',
#  'flesh',
#  'terrible',
#  'news',
#  'bell',
#  'adults',
#  'law',
#  'explicit',
#  'tire',
#  'likable',
#  'solid',
#  'beauty',
#  'final',
#  'refuse',
#  'period',
#  'rule',
#  'bear',
#  'intend',
#  'overcome',
#  'worry',
#  'bar',
#  'challenge',
#  'cheat',
#  'cold',
#  'imagination',
#  'inside',
#  'similar',
#  'towards',
#  'heavy',
#  'team',
#  'avoid',
#  'holly',
#  'abuse',
#  'outside',
#  'smart',
#  'city',
#  'seek',
#  'low',
#  'rough',
#  'frustrate',
#  'release',
#  'current',
#  'obvious',
#  'emotion',
#  'mysterious',
#  'section',
#  'werewolves',
#  'elements',
#  'protagonist',
#  'college',
#  'american',
#  'wild',
#  'purpose',
#  'chase',
#  'support',
#  'ride',
#  'door',
#  'physical',
#  'barely',
#  'nick',
#  'society',
#  'size',
#  'sight',
#  'effort',
#  'scar',
#  'military',
#  'white',
#  'aside',
#  'product',
#  'verne',
#  'center',
#  'forgive',
#  'dog',
#  'intense',
#  'letter',
#  'fly',
#  'resolve',
#  'loose',
#  'nicely',
#  'exist',
#  'girls',
#  'cole',
#  'usual',
#  'front',
#  'introduction',
#  'awful',
#  'mine',
#  'heal',
#  'henry',
#  'younger',
#  'constantly',
#  'spoil',
#  'incredibly',
#  'fascinate',
#  'personally',
#  'impress',
#  'gift',
#  'powerful',
#  'ryan',
#  'handsome',
#  'magical',
#  'adam',
#  'robyn',
#  'clearly',
#  'ranch',
#  'smile',
#  'likeable',
#  'whatever',
#  'rock',
#  'general',
#  'rachel',
#  'raise',
#  'holiday',
#  'island',
#  'skim',
#  'common',
#  'whose',
#  'large',
#  'b',
#  'minute',
#  'cost',
#  'total',
#  'mistress',
#  'thrill',
#  'track',
#  'rate',
#  'installment',
#  'shifters',
#  'six',
#  'charlie',
#  'joe',
#  ...]

# %%
w2v_model.corpus_count
# Out:
# 12000

# %%
w2v_model.wv.similar_by_word('good')
# Out:
# [('great', 0.7534403204917908),
#  ('like', 0.6285196542739868),
#  ('decent', 0.6260990500450134),
#  ('enjoy', 0.5719382166862488),
#  ('interest', 0.5391126275062561),
#  ('ok', 0.5362613797187805),
#  ('really', 0.5169742107391357),
#  ('think', 0.5144931077957153),
#  ('story', 0.5121291279792786),
#  ('much', 0.5112844109535217)]

# %%
w2v_model.wv['good'].shape
# Out:
# (100,)

# %%
def avg_w2v(doc):
    return np.mean([w2v_model.wv[word] for word in doc if word in w2v_model.wv.key_to_index], axis=0)

# %%
from tqdm import tqdm
X_w2v = []
for i in tqdm(range(len(lemmatized_word))):
    X_w2v.append(avg_w2v(lemmatized_word[i]))
# Out:
# 100%|██████████| 12000/12000 [00:01<00:00, 11328.18it/s]

# %%
X_w2v
# Out:
# [array([ 2.33044162e-01, -6.68643713e-01, -3.76116425e-01, -4.42096263e-01,
#         -2.43116662e-01,  6.87680066e-01, -2.17695743e-01, -1.47070244e-01,
#          3.87278229e-01,  1.77986681e-01,  6.69539848e-04,  2.99511820e-01,
#         -2.02045545e-01,  2.55047786e-03, -8.58846158e-02,  9.90136787e-02,
#          0.10134275, -0.01874389, -0.6561746 ,  0.11085778,  0.34925523,
#         -0.08154796, -0.4398574 , -0.7116181 ,  0.19341218, -0.23381256,
#          0.08524234, -0.29052937, -0.63290066,  0.21097006, -0.5191665 ,
#         -0.1197208 ,  0.34340402, -0.04987524,  0.8055679 , -0.48642313,
#          0.59134513, -0.16455339,  0.15189159, -0.674077  , -0.5433511 ,
#         -0.03130915,  0.3020836 , -0.33602116, -0.4236958 ,  0.09682138,
#         -0.43948126, -0.36569807, -0.4729503 , -0.7131296 , -0.34217605,
#         -0.83635205, -0.18811053,  0.14433381, -0.18757665, -0.21630333],
#        dtype=float32),
#  array([ 0.03629288, -0.75765646, -0.3067048 , -0.2563413 , -0.12498527,
#          0.6067857 , -0.8907744 , -1.3886187 ,  0.47697422,  0.40312597,
#         -0.19370946,  0.7110483 ,  0.01730328,  0.16110365,  0.17047143,
#          0.02498598,  0.01061428,  0.6566176 ,  0.07473294,  0.8702055 ,
#         -0.2753554 , -0.9760744 ,  0.5459429 ,  0.2682583 , -0.13502745,
#          0.19782685,  0.8256299 , -0.17517892,  0.98546463, -0.34330994,
#         -0.9014398 , -0.5661688 , -0.42922544,  0.41757843, -0.12057074,
#          0.3873425 ,  0.505305  , -0.07696736,  0.13237105,  0.5540544 ,
#         -0.7151586 ,  0.31774846,  0.2787513 ,  0.43407425, -0.34596545,
#         -0.307471  ,  0.31234387,  0.16846584, -1.0754712 ,  0.18325734,
#          0.52357453,  0.59683895,  0.07390815,  0.16922686, -0.3268776 ,
#         -0.428197  ,  0.15927468, -0.25579926, -0.21397601, -0.2492022 ,
#          0.6669213 ,  0.06568776,  0.09774821, -0.2546942 ,  0.7446607 ,
#         -0.38914487, -0.32009077,  0.11572182,  0.17920534, -0.15555266,
#          0.68049175, -0.6363392 , -0.10382945,  0.08192728,  0.07636458,
#          0.42511076,  0.04370023, -0.5430251 ,  0.75043285,  0.14037192,
#         -0.10394822, -0.39148474,  0.40808344, -0.5567807 ,  0.00398804,
#          0.47414097, -0.02751139, -0.2858448 , -0.6256751 ,  0.5941821 ,
#          0.14908831, -0.25599667,  0.03516549,  0.5145992 , -0.65078354,
#          0.5220421 , -0.22338149,  0.12208617,  0.38511735, -0.64114   ],
#        dtype=float32),
#  ...]

# %%
X_new_w2v = np.array(X_w2v)

# %%
X_new_w2v[0].shape
# Out:
# (100,)

# %%
y = reviews['rating'].to_numpy()

# %%
df = pd.DataFrame(X_new_w2v)
df['Output'] = y
X_new_w2v = df
y = df['Output']

# %%
from sklearn.model_selection import train_test_split
X_train_w2v, X_test_w2v, y_train_w2v, y_test_w2v = train_test_split(X_new_w2v, y, test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB
nb_model_w2v = GaussianNB().fit(X_train_w2v, y_train_w2v)
# Out:
# c:\Users\91780\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
y_pred_w2v = nb_model_w2v.predict(X_test_w2v)
# Out:
# c:\Users\91780\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
print("W2V accuracy: ", accuracy_score(y_test_w2v, y_pred_w2v))
# Out:
# W2V accuracy:  1.0
